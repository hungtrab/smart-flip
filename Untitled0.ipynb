# %%
# %cd /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/smart-flip
# Out:
# /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/smart-flip

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 6.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 92.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 50.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 17.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 53.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.2/314.2 kB 37.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 13.5 MB/s eta 0:00:00
# ...

# %%
# !chmod +x ./scripts/bash/smart_flip/gptq/run_llama31_tuning_4b.sh

# %%
# !RUN_FLOAT_MODEL=0 INCLUDE_LM_EVAL=0 ./scripts/bash/smart_flip/gptq/run_mistral.sh

# %%
# !bash scripts/bash/smart_flip/gptq/run_mistral_from_existing_raw.sh

# %%
# !RUN_FLOAT_MODEL=0 ./scripts/bash/smart_flip/gptq/run_llama31.sh

# %%
# !bash scripts/bash/bias_correction/gptq/run_mistral_from_existing_raw_3bit.sh

# %%
# !RUN_FLOAT_MODEL=0 bash scripts/bash/smart_flip/gptq/run_llama31.sh
# Out:
# ==> skipping float_model :: meta-llama/Llama-3.1-8B
# ==> raw_quantize :: meta-llama/Llama-3.1-8B :: origin=gptq
# Loading checkpoint shards: 100% 4/4 [00:00<00:00,  6.06it/s]
#
# [C4 Calibration Data - Optimized]
#   Samples: 128
#   Sequence length: 2048 tokens
#   Seed: 42
#   Loading calibration cache: data/cache/calibration/c4_calib_n128_len2048_seed42_tensorsTrue_tokmeta-llama-Llama-3.1-8B-d5b5cc874b.pkl
#
# [GPTQ Quantizer Initialized]
#   Config: GPTQConfig(bits=4, group_size=1, percdamp=0.01, sym=False, act_order=True, true_sequential=True, static_groups=False, mse=False, max_bias_samples=4096)
#   Post correction: none
#
# ...
# GPTQ Sequential Quantization
# ...
#
# [Layer 1/32]
#   Quantizing self_attn.k_proj
# time 4.16
# error 1.4307830094317797e-11
#   Quantizing self_attn.v_proj
# time 3.53
# error 1.4989025916723603e-13
#   Quantizing self_attn.q_proj
# time 3.50
# error 2.4034212120493947e-11
#   Quantizing self_attn.o_proj
# time 3.72
# error 1.0591046709616542e-14
# ...

# %%
# !RUN_FLOAT_MODEL=0 ./scripts/bash/bias_correction/gptq/run_llama31.sh

# %%
# !RUN_FLOAT_MODEL=0 ./scripts/bash/smart_flip/gptq/run_llama31_tuning_4b.sh
