# %%
# %cd /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/smart-flip
# Out:
# /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/smart-flip

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.0.2)
# Collecting transformers==4.45.0 (from -r requirements.txt (line 3))
#   Downloading transformers-4.45.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.4 MB/s eta 0:00:00
# Collecting datasets==2.17.1 (from -r requirements.txt (line 4))
#   Downloading datasets-2.17.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (5.9.5)
# Collecting lm-eval==0.4.9.1 (from -r requirements.txt (line 7))
#   Downloading lm_eval-0.4.9.1-py3-none-any.whl.metadata (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (0.26.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (1.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.0->-r requirements.txt (line 3)) (3.29.0)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers==4.45.0->-r requirements.txt (line 3))
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.0->-r requirements.txt (line 3)) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.0->-r requirements.txt (line 3)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.0->-r requirements.txt (line 3)) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.0->-r requirements.txt (line 3)) (2.32.4)
# Collecting tokenizers<0.21,>=0.20 (from transformers==4.45.0->-r requirements.txt (line 3))
#   Downloading tokenizers-0.20.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.45.0->-r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets==2.17.1->-r requirements.txt (line 4)) (18.1.0)
# Collecting pyarrow-hotfix (from datasets==2.17.1->-r requirements.txt (line 4))
#   Downloading pyarrow_hotfix-0.7-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets==2.17.1->-r requirements.txt (line 4)) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets==2.17.1->-r requirements.txt (line 4)) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets==2.17.1->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from datasets==2.17.1->-r requirements.txt (line 4)) (0.70.16)
# Collecting fsspec<=2023.10.0,>=2023.1.0 (from fsspec[http]<=2023.10.0,>=2023.1.0->datasets==2.17.1->-r requirements.txt (line 4))
#   Downloading fsspec-2023.10.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from datasets==2.17.1->-r requirements.txt (line 4)) (3.13.5)
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.12/dist-packages (from lm-eval==0.4.9.1->-r requirements.txt (line 7)) (1.13.0)
# Collecting evaluate (from lm-eval==0.4.9.1->-r requirements.txt (line 7))
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Collecting jsonlines (from lm-eval==0.4.9.1->-r requirements.txt (line 7))
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.12/dist-packages (from lm-eval==0.4.9.1->-r requirements.txt (line 7)) (2.14.1)
# Requirement already satisfied: peft>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from lm-eval==0.4.9.1->-r requirements.txt (line 7)) (0.19.1)
# Collecting pybind11>=2.6.2 (from lm-eval==0.4.9.1->-r requirements.txt (line 7))
#   Downloading pybind11-3.0.4-py3-none-any.whl.metadata (10 kB)
# Collecting pytablewriter (from lm-eval==0.4.9.1->-r requirements.txt (line 7))
#   Downloading pytablewriter-1.2.1-py3-none-any.whl.metadata (38 kB)
# Collecting rouge-score>=0.0.4 (from lm-eval==0.4.9.1->-r requirements.txt (line 7))
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sacrebleu>=1.5.0 (from lm-eval==0.4.9.1->-r requirements.txt (line 7))
#   Downloading sacrebleu-2.6.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from lm-eval==0.4.9.1->-r requirements.txt (line 7)) (1.6.1)
# Collecting sqlitedict (from lm-eval==0.4.9.1->-r requirements.txt (line 7))
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.12/dist-packages (from lm-eval==0.4.9.1->-r requirements.txt (line 7)) (2.10.0+cu128)
# Collecting tqdm-multiprocess (from lm-eval==0.4.9.1->-r requirements.txt (line 7))
#   Downloading tqdm_multiprocess-0.0.11-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: zstandard in /usr/local/lib/python3.12/dist-packages (from lm-eval==0.4.9.1->-r requirements.txt (line 7)) (0.25.0)
# Collecting word2number (from lm-eval==0.4.9.1->-r requirements.txt (line 7))
#   Downloading word2number-1.1.zip (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.12/dist-packages (from lm-eval==0.4.9.1->-r requirements.txt (line 7)) (10.8.0)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 8)) (8.3.3)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 8)) (3.1.47)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 8)) (4.9.6)
# Requirement already satisfied: protobuf!=5.28.0,!=5.29.0,<8,>4.21.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 8)) (5.29.6)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 8)) (2.12.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 8)) (2.58.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.12/dist-packages (from wandb->-r requirements.txt (line 8)) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.17.1->-r requirements.txt (line 4)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.17.1->-r requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.17.1->-r requirements.txt (line 4)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.17.1->-r requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.17.1->-r requirements.txt (line 4)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.17.1->-r requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==2.17.1->-r requirements.txt (line 4)) (1.23.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 8)) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.45.0->-r requirements.txt (line 3)) (1.4.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->-r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->-r requirements.txt (line 8)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb->-r requirements.txt (line 8)) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.45.0->-r requirements.txt (line 3)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.45.0->-r requirements.txt (line 3)) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.45.0->-r requirements.txt (line 3)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.45.0->-r requirements.txt (line 3)) (2026.4.22)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge-score>=0.0.4->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from rouge-score>=0.0.4->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge-score>=0.0.4->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (1.17.0)
# Collecting portalocker (from sacrebleu>=1.5.0->lm-eval==0.4.9.1->-r requirements.txt (line 7))
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from sacrebleu>=1.5.0->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (0.9.0)
# Collecting colorama (from sacrebleu>=1.5.0->lm-eval==0.4.9.1->-r requirements.txt (line 7))
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sacrebleu>=1.5.0->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (6.1.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.1->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.1->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.1->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==2.17.1->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==2.17.1->-r requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==2.17.1->-r requirements.txt (line 4)) (2026.1)
# Collecting DataProperty<2,>=1.1.0 (from pytablewriter->lm-eval==0.4.9.1->-r requirements.txt (line 7))
#   Downloading dataproperty-1.1.1-py3-none-any.whl.metadata (12 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter->lm-eval==0.4.9.1->-r requirements.txt (line 7))
#   Downloading mbstrdecoder-1.1.5-py3-none-any.whl.metadata (4.3 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter->lm-eval==0.4.9.1->-r requirements.txt (line 7))
#   Downloading pathvalidate-3.3.1-py3-none-any.whl.metadata (12 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter->lm-eval==0.4.9.1->-r requirements.txt (line 7))
#   Downloading tabledata-1.3.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter->lm-eval==0.4.9.1->-r requirements.txt (line 7))
#   Downloading tcolorpy-0.1.7-py3-none-any.whl.metadata (6.3 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm-eval==0.4.9.1->-r requirements.txt (line 7))
#   Downloading typepy-1.3.5-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 8)) (5.0.3)
# Requirement already satisfied: chardet<7,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (5.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8->lm-eval==0.4.9.1->-r requirements.txt (line 7)) (3.0.3)
# Downloading transformers-4.45.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 92.4 MB/s eta 0:00:00
# Downloading datasets-2.17.1-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 47.2 MB/s eta 0:00:00
# Downloading lm_eval-0.4.9.1-py3-none-any.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 126.9 MB/s eta 0:00:00
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 10.2 MB/s eta 0:00:00
# Downloading fsspec-2023.10.0-py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 21.0 MB/s eta 0:00:00
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 55.5 MB/s eta 0:00:00
# Downloading pybind11-3.0.4-py3-none-any.whl (314 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.2/314.2 kB 38.6 MB/s eta 0:00:00
# Downloading sacrebleu-2.6.0-py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 14.2 MB/s eta 0:00:00
# Downloading tokenizers-0.20.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 130.2 MB/s eta 0:00:00
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading pyarrow_hotfix-0.7-py3-none-any.whl (7.9 kB)
# Downloading pytablewriter-1.2.1-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 12.0 MB/s eta 0:00:00
# Downloading tqdm_multiprocess-0.0.11-py3-none-any.whl (9.8 kB)
# Downloading dataproperty-1.1.1-py3-none-any.whl (27 kB)
# Downloading mbstrdecoder-1.1.5-py3-none-any.whl (8.0 kB)
# Downloading pathvalidate-3.3.1-py3-none-any.whl (24 kB)
# Downloading tabledata-1.3.5-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.7-py3-none-any.whl (8.1 kB)
# Downloading typepy-1.3.5-py3-none-any.whl (31 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: rouge-score, sqlitedict, word2number
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=dde9dec18521ed742de43d9dcc3ef7773bf62811f27d6897a81d942db06e3535
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16862 sha256=ea359f20fcc0e2609787d9c7b59e26a0f18ea74ec84ade0cf91c5a8cc6c6184b
#   Stored in directory: /root/.cache/pip/wheels/7a/6f/21/fc016aef45ffcabe27129a2252f061387cbf278d2086225a64
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5568 sha256=58433b3fa5194008c3e86b039cc97cb739802a04a191e5c1811c19c729a984ee
#   Stored in directory: /root/.cache/pip/wheels/5b/79/fb/d25928e599c7e11fe4e00d32048cd74933f34a74c633d2aea6
# Successfully built rouge-score sqlitedict word2number
# Installing collected packages: word2number, sqlitedict, tcolorpy, pybind11, pyarrow-hotfix, portalocker, pathvalidate, mbstrdecoder, jsonlines, fsspec, colorama, typepy, tqdm-multiprocess, sacrebleu, rouge-score, huggingface-hub, tokenizers, transformers, datasets, DataProperty, tabledata, evaluate, pytablewriter, lm-eval
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.11.0
#     Uninstalling huggingface_hub-1.11.0:
#       Successfully uninstalled huggingface_hub-1.11.0
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.2
#     Uninstalling tokenizers-0.22.2:
#       Successfully uninstalled tokenizers-0.22.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2023.10.0 which is incompatible.
# Successfully installed DataProperty-1.1.1 colorama-0.4.6 datasets-2.17.1 evaluate-0.4.6 fsspec-2023.10.0 huggingface-hub-0.36.2 jsonlines-4.0.0 lm-eval-0.4.9.1 mbstrdecoder-1.1.5 pathvalidate-3.3.1 portalocker-3.2.0 pyarrow-hotfix-0.7 pybind11-3.0.4 pytablewriter-1.2.1 rouge-score-0.1.2 sacrebleu-2.6.0 sqlitedict-2.1.0 tabledata-1.3.5 tcolorpy-0.1.7 tokenizers-0.20.3 tqdm-multiprocess-0.0.11 transformers-4.45.0 typepy-1.3.5 word2number-1.1

# %%
# !chmod +x ./scripts/bash/smart_flip/gptq/run_mistral.sh

# %%
# !RUN_FLOAT_MODEL=0 INCLUDE_LM_EVAL=0 ./scripts/bash/smart_flip/gptq/run_mistral.sh
# Out:
# ==> skipping float_model :: mistralai/Mistral-7B-v0.3
# ==> raw_quantize :: mistralai/Mistral-7B-v0.3 :: origin=gptq
# tokenizer_config.json: 137kB [00:00, 169MB/s]
# tokenizer.model: 100% 587k/587k [00:00<00:00, 837kB/s]
# tokenizer.json: 1.96MB [00:00, 49.6MB/s]
# special_tokens_map.json: 100% 414/414 [00:00<00:00, 4.27MB/s]
# config.json: 100% 601/601 [00:00<00:00, 6.87MB/s]
# model.safetensors.index.json: 23.9kB [00:00, 89.6MB/s]
# Downloading shards:   0% 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0% 0.00/4.95G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0% 0.00/4.95G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0% 0.00/4.95G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0% 0.00/4.95G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0% 0.00/4.95G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0% 0.00/4.95G [00:01<?, ?B/s]
# model-00001-of-00003.safetensors:   1% 73.0M/4.95G [00:01<00:13, 365MB/s]
# model-00001-of-00003.safetensors:   4% 207M/4.95G [00:01<00:13, 343MB/s]
# model-00001-of-00003.safetensors:   6% 274M/4.95G [00:01<00:13, 340MB/s]
# model-00001-of-00003.safetensors:   8% 408M/4.95G [00:02<00:10, 450MB/s]
# model-00001-of-00003.safetensors:  11% 542M/4.95G [00:02<00:11, 394MB/s]
# model-00001-of-00003.safetensors:  16% 768M/4.95G [00:02<00:09, 464MB/s]
# model-00001-of-00003.safetensors:  23% 1.15G/4.95G [00:03<00:08, 468MB/s]
# model-00001-of-00003.safetensors:  29% 1.41G/4.95G [00:04<00:06, 525MB/s]
# model-00001-of-00003.safetensors:  37% 1.82G/4.95G [00:04<00:06, 515MB/s]
# model-00001-of-00003.safetensors:  54% 2.69G/4.95G [00:06<00:03, 572MB/s]
# model-00001-of-00003.safetensors:  87% 4.30G/4.95G [00:10<00:01, 427MB/s]
# model-00001-of-00003.safetensors: 100% 4.95G/4.95G [00:13<00:00, 358MB/s]
# Downloading shards:  33% 1/3 [00:13<00:27, 13.91s/it]
# model-00002-of-00003.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0% 0.00/5.00G [00:01<?, ?B/s]
# model-00002-of-00003.safetensors:   0% 0.00/5.00G [00:01<?, ?B/s]
# model-00002-of-00003.safetensors:   0% 0.00/5.00G [00:01<?, ?B/s]
# model-00002-of-00003.safetensors:   0% 0.00/5.00G [00:01<?, ?B/s]
# model-00002-of-00003.safetensors:   0% 0.00/5.00G [00:01<?, ?B/s]
# model-00002-of-00003.safetensors:   0% 0.00/5.00G [00:02<?, ?B/s]
# model-00002-of-00003.safetensors:   0% 0.00/5.00G [00:02<?, ?B/s]
# model-00002-of-00003.safetensors:   0% 0.00/5.00G [00:02<?, ?B/s]
# model-00002-of-00003.safetensors:   1% 67.1M/5.00G [00:02<00:14, 335MB/s]
# model-00002-of-00003.safetensors:   9% 469M/5.00G [00:03<00:05, 832MB/s]
# model-00002-of-00003.safetensors:  20% 1.02G/5.00G [00:03<00:02, 1.48GB/s]
# model-00002-of-00003.safetensors:  25% 1.27G/5.00G [00:03<00:03, 1.07GB/s]
# model-00002-of-00003.safetensors:  31% 1.54G/5.00G [00:04<00:04, 749MB/s]
# model-00002-of-00003.safetensors:  43% 2.15G/5.00G [00:05<00:03, 751MB/s]
# model-00002-of-00003.safetensors:  59% 2.95G/5.00G [00:10<00:07, 261MB/s]
# model-00002-of-00003.safetensors:  91% 4.56G/5.00G [00:11<00:00, 459MB/s]
# model-00002-of-00003.safetensors: 100% 5.00G/5.00G [00:12<00:00, 390MB/s]
# Downloading shards:  67% 2/3 [00:26<00:13, 13.33s/it]
# model-00003-of-00003.safetensors:   0% 0.00/4.55G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0% 0.00/4.55G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0% 0.00/4.55G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0% 0.00/4.55G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0% 16.7M/4.55G [00:00<00:54, 83.7MB/s]
# model-00003-of-00003.safetensors:   1% 55.2M/4.55G [00:01<00:30, 147MB/s]
# model-00003-of-00003.safetensors:   3% 122M/4.55G [00:01<00:18, 233MB/s]
# model-00003-of-00003.safetensors:   4% 189M/4.55G [00:01<00:15, 273MB/s]
# model-00003-of-00003.safetensors:   6% 268M/4.55G [00:01<00:13, 317MB/s]
# model-00003-of-00003.safetensors:   8% 344M/4.55G [00:01<00:12, 338MB/s]
# model-00003-of-00003.safetensors:  12% 543M/4.55G [00:02<00:09, 417MB/s]
# model-00003-of-00003.safetensors:  15% 677M/4.55G [00:02<00:08, 483MB/s]
# model-00003-of-00003.safetensors:  18% 811M/4.55G [00:02<00:06, 534MB/s]
# model-00003-of-00003.safetensors:  21% 945M/4.55G [00:02<00:06, 572MB/s]
# model-00003-of-00003.safetensors:  24% 1.08G/4.55G [00:03<00:05, 600MB/s]
# model-00003-of-00003.safetensors:  30% 1.35G/4.55G [00:03<00:05, 632MB/s]
# model-00003-of-00003.safetensors:  33% 1.48G/4.55G [00:03<00:05, 516MB/s]
# model-00003-of-00003.safetensors:  43% 1.95G/4.55G [00:07<00:12, 214MB/s]
# model-00003-of-00003.safetensors:  78% 3.56G/4.55G [00:11<00:03, 316MB/s]
# model-00003-of-00003.safetensors: 100% 4.55G/4.55G [00:12<00:00, 379MB/s]
# Downloading shards: 100% 3/3 [00:39<00:00, 13.01s/it]
# Loading checkpoint shards: 100% 3/3 [00:00<00:00,  6.19it/s]
# generation_config.json: 100% 116/116 [00:00<00:00, 1.21MB/s]
#
# [C4 Calibration Data - Optimized]
#   Samples: 128
#   Sequence length: 2048 tokens
#   Seed: 42
#   Loading calibration cache: data/cache/calibration/c4_calib_n128_len2048_seed42_tensorsTrue_tokmistralai-Mistral-7B-v0.3-f78f672720.pkl
#
# [GPTQ Quantizer Initialized]
#   Config: GPTQConfig(bits=3, group_size=128, percdamp=0.01, sym=True, act_order=False, true_sequential=True, static_groups=False, mse=False, max_bias_samples=4096)
#   Post correction: none
#
# ================================================================================
# GPTQ Sequential Quantization
# ================================================================================
#
# [Layer 1/32]
#   Quantizing self_attn.k_proj
# time 2.64
# error 994.851806640625
#   Quantizing self_attn.v_proj
# time 2.06
# error 25.34325408935547
#   Quantizing self_attn.q_proj
# time 2.02
# error 2831.95166015625
#   Quantizing self_attn.o_proj
# time 2.03
# error 0.32495468854904175
#   Quantizing mlp.up_proj
# time 2.23
# error 1903.477294921875
#   Quantizing mlp.gate_proj
# time 2.07
# error 2212.44970703125
#   Quantizing mlp.down_proj
# time 7.61
# error 2.226069211959839
#
# [Layer 2/32]
#   Quantizing self_attn.k_proj
# time 2.03
# error 2547.3486328125
#   Quantizing self_attn.v_proj
# time 2.03
# error 334.6441955566406
#   Quantizing self_attn.q_proj
# time 2.03
# error 5374.525390625
#   Quantizing self_attn.o_proj
# time 2.03
# error 1.032160997390747
#   Quantizing mlp.up_proj
# time 2.08
# error 5859.7265625
#   Quantizing mlp.gate_proj
# time 2.07
# error 6725.732421875
#   Quantizing mlp.down_proj
# time 7.66
# error 317.82098388671875
#
# [Layer 3/32]
#   Quantizing self_attn.k_proj
# time 2.04
# error 18997.73046875
#   Quantizing self_attn.v_proj
# time 2.03
# error 2449.29541015625
#   Quantizing self_attn.q_proj
# time 2.07
# error 39713.03125
#   Quantizing self_attn.o_proj
# time 2.02
# error 0.9485574960708618
#   Quantizing mlp.up_proj
# time 2.09
# error 11390.3701171875
#   Quantizing mlp.gate_proj
# time 2.07
# error 13074.72265625
#   Quantizing mlp.down_proj
# time 7.63
# error 4.956468105316162
#
# [Layer 4/32]
#   Quantizing self_attn.k_proj
# time 2.03
# error 10346.1728515625
#   Quantizing self_attn.v_proj
# time 2.02
# error 1617.79443359375
#   Quantizing self_attn.q_proj
# time 2.02
# error 21287.09375
#   Quantizing self_attn.o_proj
# time 2.07
# error 2.0478718280792236
#   Quantizing mlp.up_proj
# time 2.06
# error 18599.275390625
#   Quantizing mlp.gate_proj
# time 2.14
# error 21565.5078125
#   Quantizing mlp.down_proj
# time 7.81
# error 9.703680038452148
#
# [Layer 5/32]
#   Quantizing self_attn.k_proj
# time 2.10
# error 16363.3798828125
#   Quantizing self_attn.v_proj
# time 2.05
# error 3082.4287109375
#   Quantizing self_attn.q_proj
# time 2.04
# error 37329.2890625
#   Quantizing self_attn.o_proj
# time 2.05
# error 2.6465835571289062
#   Quantizing mlp.up_proj
# time 2.07
# error 25924.75390625
#   Quantizing mlp.gate_proj
# time 2.08
# error 32009.74609375
#   Quantizing mlp.down_proj
# time 7.66
# error 18.985816955566406
#
# [Layer 6/32]
#   Quantizing self_attn.k_proj
# time 2.04
# error 22574.68359375
#   Quantizing self_attn.v_proj
# time 2.02
# error 3558.1435546875
#   Quantizing self_attn.q_proj
# time 2.06
# error 50780.15625
#   Quantizing self_attn.o_proj
# time 2.04
# error 8.937183380126953
#   Quantizing mlp.up_proj
# time 2.07
# error 35273.97265625
#   Quantizing mlp.gate_proj
# time 2.07
# error 46279.2265625
#   Quantizing mlp.down_proj
# time 7.71
# error 33.9244499206543
#
# [Layer 7/32]
#   Quantizing self_attn.k_proj
# time 2.04
# error 23487.427734375
#   Quantizing self_attn.v_proj
# time 2.03
# error 3848.294189453125
#   Quantizing self_attn.q_proj
# time 2.13
# error 50075.390625
#   Quantizing self_attn.o_proj
# time 2.02
# error 9.919353485107422
#   Quantizing mlp.up_proj
# time 2.05
# error 44524.6796875
#   Quantizing mlp.gate_proj
# time 2.04
# error 57303.4375
#   Quantizing mlp.down_proj
# time 7.61
# error 49.46867752075195
#
# [Layer 8/32]
#   Quantizing self_attn.k_proj
# time 2.02
# error 30785.341796875
#   Quantizing self_attn.v_proj
# time 2.01
# error 4880.57958984375
#   Quantizing self_attn.q_proj
# time 2.00
# error 63684.5390625
#   Quantizing self_attn.o_proj
# time 2.02
# error 18.838611602783203
#   Quantizing mlp.up_proj
# time 2.08
# error 52834.765625
#   Quantizing mlp.gate_proj
# time 2.09
# error 69647.71875
#   Quantizing mlp.down_proj
# time 7.58
# error 65.13809204101562
#
# [Layer 9/32]
#   Quantizing self_attn.k_proj
# time 2.12
# error 24567.20703125
#   Quantizing self_attn.v_proj
# time 2.09
# error 4892.1572265625
#   Quantizing self_attn.q_proj
# time 2.01
# error 53620.85546875
#   Quantizing self_attn.o_proj
# time 2.04
# error 20.842082977294922
#   Quantizing mlp.up_proj
# time 2.06
# error 60009.9375
#   Quantizing mlp.gate_proj
# time 2.15
# error 77667.453125
#   Quantizing mlp.down_proj
# time 7.60
# error 75.08747100830078
#
# [Layer 10/32]
#   Quantizing self_attn.k_proj
# time 2.05
# error 36260.9609375
#   Quantizing self_attn.v_proj
# time 2.03
# error 6139.76953125
#   Quantizing self_attn.q_proj
# time 2.01
# error 76559.25
#   Quantizing self_attn.o_proj
# time 2.02
# error 29.162826538085938
#   Quantizing mlp.up_proj
# time 2.06
# error 65964.03125
#   Quantizing mlp.gate_proj
# time 2.07
# error 82716.6171875
#   Quantizing mlp.down_proj
# time 7.75
# error 93.97503662109375
#
# [Layer 11/32]
#   Quantizing self_attn.k_proj
# time 2.38
# error 31681.529296875
#   Quantizing self_attn.v_proj
# time 2.02
# error 5158.52197265625
#   Quantizing self_attn.q_proj
# time 2.01
# error 65987.328125
#   Quantizing self_attn.o_proj
# time 2.02
# error 41.99285888671875
#   Quantizing mlp.up_proj
# time 2.04
# error 70877.484375
#   Quantizing mlp.gate_proj
# time 2.17
# error 86452.21875
#   Quantizing mlp.down_proj
# time 7.63
# error 111.65127563476562
#
# [Layer 12/32]
#   Quantizing self_attn.k_proj
# time 2.09
# error 39122.1484375
#   Quantizing self_attn.v_proj
# time 2.06
# error 7873.66796875
#   Quantizing self_attn.q_proj
# time 2.02
# error 83159.5625
#   Quantizing self_attn.o_proj
# time 2.01
# error 55.62510681152344
#   Quantizing mlp.up_proj
# time 2.06
# error 78989.234375
#   Quantizing mlp.gate_proj
# time 2.05
# error 94838.609375
#   Quantizing mlp.down_proj
# time 7.91
# error 129.61611938476562
#
# [Layer 13/32]
#   Quantizing self_attn.k_proj
# time 2.03
# error 50215.546875
#   Quantizing self_attn.v_proj
# time 2.04
# error 8900.416015625
#   Quantizing self_attn.q_proj
# time 2.03
# error 108353.3984375
#   Quantizing self_attn.o_proj
# time 2.03
# error 72.32415771484375
#   Quantizing mlp.up_proj
# time 2.13
# error 88640.3125
#   Quantizing mlp.gate_proj
# time 2.16
# error 104217.6171875
#   Quantizing mlp.down_proj
# time 7.76
# error 160.11416625976562
#
# [Layer 14/32]
#   Quantizing self_attn.k_proj
# time 2.05
# error 43167.390625
#   Quantizing self_attn.v_proj
# time 2.04
# error 8425.8212890625
#   Quantizing self_attn.q_proj
# time 2.03
# error 85539.515625
#   Quantizing self_attn.o_proj
# time 2.01
# error 88.229736328125
#   Quantizing mlp.up_proj
# time 2.10
# error 101948.59375
#   Quantizing mlp.gate_proj
# time 2.03
# error 116497.9140625
#   Quantizing mlp.down_proj
# time 7.60
# error 201.9933319091797
#
# [Layer 15/32]
#   Quantizing self_attn.k_proj
# time 2.04
# error 45724.8359375
#   Quantizing self_attn.v_proj
# time 2.02
# error 13638.833984375
#   Quantizing self_attn.q_proj
# time 2.04
# error 101850.515625
#   Quantizing self_attn.o_proj
# time 2.00
# error 113.09502410888672
#   Quantizing mlp.up_proj
# time 2.09
# error 115343.03125
#   Quantizing mlp.gate_proj
# time 2.20
# error 132299.890625
#   Quantizing mlp.down_proj
# time 7.61
# error 270.080810546875
#
# [Layer 16/32]
#   Quantizing self_attn.k_proj
# time 2.02
# error 59435.69921875
#   Quantizing self_attn.v_proj
# time 2.02
# error 16100.4970703125
#   Quantizing self_attn.q_proj
# time 2.03
# error 128117.203125
#   Quantizing self_attn.o_proj
# time 2.02
# error 137.48143005371094
#   Quantizing mlp.up_proj
# time 2.75
# error 129259.8828125
#   Quantizing mlp.gate_proj
# time 2.06
# error 153593.21875
#   Quantizing mlp.down_proj
# time 7.86
# error 343.4891357421875
#
# [Layer 17/32]
#   Quantizing self_attn.k_proj
# time 2.05
# error 56494.734375
#   Quantizing self_attn.v_proj
# time 2.03
# error 15315.7939453125
#   Quantizing self_attn.q_proj
# time 2.10
# error 116126.53125
#   Quantizing self_attn.o_proj
# time 2.08
# error 159.79171752929688
#   Quantizing mlp.up_proj
# time 2.12
# error 152936.3125
#   Quantizing mlp.gate_proj
# time 2.06
# error 192414.59375
#   Quantizing mlp.down_proj
# time 7.66
# error 473.52593994140625
#
# [Layer 18/32]
#   Quantizing self_attn.k_proj
# time 2.02
# error 45632.58203125
#   Quantizing self_attn.v_proj
# time 2.02
# error 14948.1533203125
#   Quantizing self_attn.q_proj
# time 2.01
# error 106087.796875
#   Quantizing self_attn.o_proj
# time 2.07
# error 164.5472412109375
#   Quantizing mlp.up_proj
# time 2.06
# error 177529.21875
#   Quantizing mlp.gate_proj
# time 2.09
# error 223627.15625
#   Quantizing mlp.down_proj
# time 7.64
# error 650.5663452148438
#
# [Layer 19/32]
#   Quantizing self_attn.k_proj
# time 2.02
# error 54825.37109375
#   Quantizing self_attn.v_proj
# time 2.04
# error 18279.173828125
#   Quantizing self_attn.q_proj
# time 2.03
# error 134371.5625
#   Quantizing self_attn.o_proj
# time 2.02
# error 185.55548095703125
#   Quantizing mlp.up_proj
# time 2.16
# error 202227.8125
#   Quantizing mlp.gate_proj
# time 2.08
# error 255151.6875
#   Quantizing mlp.down_proj
# time 7.60
# error 937.841796875
#
# [Layer 20/32]
#   Quantizing self_attn.k_proj
# time 2.03
# error 55770.828125
#   Quantizing self_attn.v_proj
# time 2.01
# error 21332.91015625
#   Quantizing self_attn.q_proj
# time 2.04
# error 125364.59375
#   Quantizing self_attn.o_proj
# time 2.02
# error 197.27455139160156
#   Quantizing mlp.up_proj
# time 2.07
# error 227503.171875
#   Quantizing mlp.gate_proj
# time 2.07
# error 292330.1875
#   Quantizing mlp.down_proj
# time 7.69
# error 1258.711669921875
#
# [Layer 21/32]
#   Quantizing self_attn.k_proj
# time 2.07
# error 58766.99609375
#   Quantizing self_attn.v_proj
# time 2.02
# error 23549.09765625
#   Quantizing self_attn.q_proj
# time 2.01
# error 137401.4375
#   Quantizing self_attn.o_proj
# time 2.02
# error 221.3095703125
#   Quantizing mlp.up_proj
# time 2.05
# error 252673.375
#   Quantizing mlp.gate_proj
# time 2.12
# error 333175.625
#   Quantizing mlp.down_proj
# time 7.84
# error 1324.9476318359375
#
# [Layer 22/32]
#   Quantizing self_attn.k_proj
# time 2.09
# error 56107.86328125
#   Quantizing self_attn.v_proj
# time 2.02
# error 24758.6484375
#   Quantizing self_attn.q_proj
# time 2.03
# error 134140.140625
#   Quantizing self_attn.o_proj
# time 2.04
# error 209.90673828125
#   Quantizing mlp.up_proj
# time 2.13
# error 277626.6875
#   Quantizing mlp.gate_proj
# time 2.09
# error 393508.1875
#   Quantizing mlp.down_proj
# time 7.77
# error 1339.095947265625
#
# [Layer 23/32]
#   Quantizing self_attn.k_proj
# time 2.04
# error 52760.2421875
#   Quantizing self_attn.v_proj
# time 2.03
# error 26076.546875
#   Quantizing self_attn.q_proj
# time 2.02
# error 128623.40625
#   Quantizing self_attn.o_proj
# time 2.02
# error 155.14268493652344
#   Quantizing mlp.up_proj
# time 2.08
# error 294977.375
#   Quantizing mlp.gate_proj
# time 2.08
# error 412201.3125
#   Quantizing mlp.down_proj
# time 7.61
# error 1383.3974609375
#
# [Layer 24/32]
#   Quantizing self_attn.k_proj
# time 2.03
# error 50921.31640625
#   Quantizing self_attn.v_proj
# time 2.01
# error 26999.033203125
#   Quantizing self_attn.q_proj
# time 2.02
# error 127277.796875
#   Quantizing self_attn.o_proj
# time 2.00
# error 228.59423828125
#   Quantizing mlp.up_proj
# time 2.06
# error 319379.90625
#   Quantizing mlp.gate_proj
# time 2.10
# error 448443.375
#   Quantizing mlp.down_proj
# time 7.64
# error 1522.0684814453125
#
# [Layer 25/32]
#   Quantizing self_attn.k_proj
# time 2.07
# error 60096.75390625
#   Quantizing self_attn.v_proj
# time 2.11
# error 30818.11328125
#   Quantizing self_attn.q_proj
# time 2.08
# error 145834.421875
#   Quantizing self_attn.o_proj
# time 2.03
# error 181.1416015625
#   Quantizing mlp.up_proj
# time 2.04
# error 348824.53125
#   Quantizing mlp.gate_proj
# time 2.07
# error 499406.46875
#   Quantizing mlp.down_proj
# time 7.64
# error 1642.323974609375
#
# [Layer 26/32]
#   Quantizing self_attn.k_proj
# time 2.05
# error 57204.265625
#   Quantizing self_attn.v_proj
# time 2.17
# error 34725.4765625
#   Quantizing self_attn.q_proj
# time 2.01
# error 143708.109375
#   Quantizing self_attn.o_proj
# time 2.03
# error 185.233642578125
#   Quantizing mlp.up_proj
# time 2.10
# error 375717.03125
#   Quantizing mlp.gate_proj
# time 2.08
# error 531353.5
#   Quantizing mlp.down_proj
# time 7.71
# error 1833.73291015625
#
# [Layer 27/32]
#   Quantizing self_attn.k_proj
# time 2.03
# error 51620.7734375
#   Quantizing self_attn.v_proj
# time 2.03
# error 36069.91796875
#   Quantizing self_attn.q_proj
# time 2.04
# error 132443.5
#   Quantizing self_attn.o_proj
# time 2.02
# error 256.3714599609375
#   Quantizing mlp.up_proj
# time 2.07
# error 398862.8125
#   Quantizing mlp.gate_proj
# time 2.10
# error 544716.375
#   Quantizing mlp.down_proj
# time 7.70
# error 2065.58447265625
#
# [Layer 28/32]
#   Quantizing self_attn.k_proj
# time 2.03
# error 49846.9609375
#   Quantizing self_attn.v_proj
# time 2.03
# error 32506.552734375
#   Quantizing self_attn.q_proj
# time 2.02
# error 132332.75
#   Quantizing self_attn.o_proj
# time 2.05
# error 286.4667663574219
#   Quantizing mlp.up_proj
# time 2.04
# error 433239.5625
#   Quantizing mlp.gate_proj
# time 2.09
# error 587532.5
#   Quantizing mlp.down_proj
# time 7.61
# error 2467.70751953125
#
# [Layer 29/32]
#   Quantizing self_attn.k_proj
# time 2.04
# error 52247.640625
#   Quantizing self_attn.v_proj
# time 2.02
# error 46245.70703125
#   Quantizing self_attn.q_proj
# time 2.02
# error 132342.5625
#   Quantizing self_attn.o_proj
# time 2.03
# error 454.18743896484375
#   Quantizing mlp.up_proj
# time 2.27
# error 479394.96875
#   Quantizing mlp.gate_proj
# time 2.06
# error 627935.75
#   Quantizing mlp.down_proj
# time 7.83
# error 3360.119140625
#
# [Layer 30/32]
#   Quantizing self_attn.k_proj
# time 2.03
# error 50851.421875
#   Quantizing self_attn.v_proj
# time 2.03
# error 64442.3125
#   Quantizing self_attn.q_proj
# time 2.02
# error 146564.09375
#   Quantizing self_attn.o_proj
# time 2.09
# error 755.8787841796875
#   Quantizing mlp.up_proj
# time 2.05
# error 493155.53125
#   Quantizing mlp.gate_proj
# time 2.04
# error 621500.875
#   Quantizing mlp.down_proj
# time 7.66
# error 4542.3310546875
#
# [Layer 31/32]
#   Quantizing self_attn.k_proj
# time 2.07
# error 48385.34375
#   Quantizing self_attn.v_proj
# time 2.03
# error 71943.921875
#   Quantizing self_attn.q_proj
# time 2.09
# error 139778.984375
#   Quantizing self_attn.o_proj
# time 2.04
# error 846.8253784179688
#   Quantizing mlp.up_proj
# time 2.22
# error 507097.75
#   Quantizing mlp.gate_proj
# time 2.05
# error 624987.375
#   Quantizing mlp.down_proj
# time 7.89
# error 6356.59423828125
#
# [Layer 32/32]
#   Quantizing self_attn.k_proj
# time 2.05
# error 44349.25
#   Quantizing self_attn.v_proj
# time 2.01
# error 73785.1171875
#   Quantizing self_attn.q_proj
# time 2.01
# error 127255.6328125
#   Quantizing self_attn.o_proj
# time 2.04
# error 1140.7344970703125
#   Quantizing mlp.up_proj
# time 2.10
# error 434745.15625
#   Quantizing mlp.gate_proj
# time 2.08
# error 551080.25
#   Quantizing mlp.down_proj
# time 7.75
# error 9230.22265625
#
# ================================================================================
# GPTQ Quantization Complete
# ================================================================================
#
# Saved gptq_raw model to results/models/gptq_raw/gptq_raw_Mistral-7B-v0.3
#
# Evaluating raw_quantize on WikiText-2...
# Loading checkpoint shards: 100% 3/3 [00:20<00:00,  6.93s/it]
#
# Evaluating raw_quantize on C4...
# Loading checkpoint shards: 100% 3/3 [00:41<00:00, 13.74s/it]
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: tungserver99 (tunjob) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.26.1
# wandb: Run data is saved locally in /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/smart-flip/wandb/run-20260519_131759-wcdtjyxv
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run gptq_raw_Mistral-7B-v0.3
# wandb: ⭐️ View project at https://wandb.ai/tunjob/egbc
# wandb: 🚀 View run at https://wandb.ai/tunjob/egbc/runs/wcdtjyxv
# wandb: ⢿ updating run metadata (1.2s)
# wandb: ⣻ updating run metadata (1.2s)
# wandb: ⣽ updating run metadata (1.2s)
# wandb: ⣾ updating run metadata (1.2s)
# wandb: ⣷ uploading config.yaml 5.8KB/5.8KB (0.1s)
# wandb: ⣷ uploading wandb-metadata.json 2.0KB/2.0KB (0.1s)
# wandb: ⣷ uploading requirements.txt 14.5KB/14.5KB (0.1s)
# wandb: ⣷ uploading wandb-summary.json 336B/336B (0.1s)
# wandb: ⣯ uploading config.yaml 5.8KB/5.8KB (0.1s)
# wandb: ⣯ uploading wandb-metadata.json 2.0KB/2.0KB (0.1s)
# wandb: ⣯ uploading requirements.txt 14.5KB/14.5KB (0.1s)
# wandb: ⣯ uploading wandb-summary.json 336B/336B (0.1s)
# wandb:
# wandb: Run history:
# wandb:         perplexity/C4 ▁
# wandb: perplexity/WikiText-2 ▁
# wandb:
# wandb: Run summary:
# wandb:            model_slug Mistral-7B-v0.3
# wandb:         perplexity/C4 9.2384
# wandb: perplexity/WikiText-2 6.75445
# wandb:          source_model mistralai/Mistral-7B...
# wandb:               variant gptq_raw
# wandb:
# wandb: 🚀 View run gptq_raw_Mistral-7B-v0.3 at: https://wandb.ai/tunjob/egbc/runs/wcdtjyxv
# wandb: ⭐️ View project at: https://wandb.ai/tunjob/egbc
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260519_131759-wcdtjyxv/logs
#
# Saved evaluation results to results/eval/gptq_raw_Mistral-7B-v0.3.json
# ==> smart_flip :: mistralai/Mistral-7B-v0.3 :: origin=gptq :: bits=3 :: knee=0.0 :: max_flip=0.05
# Loading checkpoint shards: 100% 3/3 [00:10<00:00,  3.50s/it]
#
# [GPTQ Quantizer Initialized]
#   Config: GPTQConfig(bits=3, group_size=128, percdamp=0.01, sym=True, act_order=False, true_sequential=True, static_groups=False, mse=False, max_bias_samples=4096)
#   Post correction: SmartFlipCorrection
#
# Saved gptq_smart_flip model to results/models/gptq_smart_flip/gptq_smart_flip_Mistral-7B-v0.3_b3_k0.0_f0.05
#
# Evaluating smart_flip_quantize on WikiText-2...
# Loading checkpoint shards: 100% 3/3 [00:13<00:00,  4.52s/it]
#
# Evaluating smart_flip_quantize on C4...
# Loading checkpoint shards: 100% 3/3 [00:11<00:00,  3.97s/it]
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: tungserver99 (tunjob) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.26.1
# wandb: Run data is saved locally in /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/smart-flip/wandb/run-20260519_143038-pvf1akxq
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run gptq_smart_flip_Mistral-7B-v0.3_b3_k0.0_f0.05
# wandb: ⭐️ View project at https://wandb.ai/tunjob/egbc
# wandb: 🚀 View run at https://wandb.ai/tunjob/egbc/runs/pvf1akxq
# wandb: ⢿ updating run metadata (0.6s)
# wandb: ⣻ updating run metadata (0.6s)
# wandb: ⣽ updating run metadata (0.6s)
# wandb: ⣾ updating run metadata (0.6s)
# wandb: ⣷ uploading history steps 0-0, summary (0.1s)
# wandb:
# wandb: Run history:
# wandb:         perplexity/C4 ▁
# wandb: perplexity/WikiText-2 ▁
# wandb:
# wandb: Run summary:
# wandb:            model_slug Mistral-7B-v0.3
# wandb:         perplexity/C4 8.28827
# wandb: perplexity/WikiText-2 5.39203
# wandb:          source_model mistralai/Mistral-7B...
# wandb:               variant gptq_smart_flip
# wandb:
# wandb: 🚀 View run gptq_smart_flip_Mistral-7B-v0.3_b3_k0.0_f0.05 at: https://wandb.ai/tunjob/egbc/runs/pvf1akxq
# wandb: ⭐️ View project at: https://wandb.ai/tunjob/egbc
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260519_143038-pvf1akxq/logs
#
# Saved evaluation results to results/eval/gptq_smart_flip_Mistral-7B-v0.3_b3_k0.0_f0.05.json

# %%
# !bash scripts/bash/smart_flip/gptq/run_mistral_from_existing_raw.sh
# Out:
# ==> eval raw GPTQ model (WikiText-2, C4, LM Eval) :: ./results/models/gptq_raw/gptq_raw_Mistral-7B-v0.3
#
# Evaluating float_model on WikiText-2...
# Loading checkpoint shards: 100% 3/3 [00:14<00:00,  4.79s/it]
#
# Evaluating float_model on C4...
# Loading checkpoint shards: 100% 3/3 [00:12<00:00,  4.02s/it]
#
# Running lm-eval for float_model on arc_easy, arc_challenge, hellaswag, piqa, winogrande, boolq, rte, openbookqa, lambada_openai...
# 2026-05-19 14:52:23.053812: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-19 14:52:24.195324: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading checkpoint shards: 100% 3/3 [00:12<00:00,  4.23s/it]
# Downloading readme: 9.00kB [00:00, 23.1MB/s]
# Downloading data: 100% 331k/331k [00:00<00:00, 1.48MB/s]
# Downloading data: 100% 346k/346k [00:00<00:00, 4.57MB/s]
# Downloading data: 100% 86.1k/86.1k [00:00<00:00, 1.27MB/s]
# Generating train split: 100% 2251/2251 [00:00<00:00, 39022.83 examples/s]
# Generating test split: 100% 2376/2376 [00:00<00:00, 535529.38 examples/s]
# Generating validation split: 100% 570/570 [00:00<00:00, 251737.74 examples/s]
# Downloading readme: 9.00kB [00:00, 33.1MB/s]
# Downloading data: 100% 190k/190k [00:00<00:00, 2.64MB/s]
# Downloading data: 100% 204k/204k [00:00<00:00, 2.87MB/s]
# Downloading data: 100% 55.7k/55.7k [00:00<00:00, 791kB/s]
# Generating train split: 100% 1119/1119 [00:00<00:00, 328257.53 examples/s]
# Generating test split: 100% 1172/1172 [00:00<00:00, 383232.58 examples/s]
# Generating validation split: 100% 299/299 [00:00<00:00, 130377.06 examples/s]
# Downloading readme: 7.02kB [00:00, 31.9MB/s]
# Downloading data: 100% 24.4M/24.4M [00:00<00:00, 122MB/s]
# Downloading data: 100% 6.11M/6.11M [00:00<00:00, 58.0MB/s]
# Downloading data: 100% 6.32M/6.32M [00:00<00:00, 70.4MB/s]
# Generating train split: 100% 39905/39905 [00:00<00:00, 261444.20 examples/s]
# Generating test split: 100% 10003/10003 [00:00<00:00, 278058.05 examples/s]
# Generating validation split: 100% 10042/10042 [00:00<00:00, 242195.21 examples/s]
# Map: 100% 39905/39905 [00:06<00:00, 6414.66 examples/s]
# Map: 100% 10042/10042 [00:01<00:00, 6805.47 examples/s]
# Downloading data: 100% 2.64M/2.64M [00:00<00:00, 25.0MB/s]
# Downloading data: 100% 300k/300k [00:00<00:00, 3.82MB/s]
# Downloading data: 100% 496k/496k [00:00<00:00, 7.00MB/s]
# Generating train split: 16113 examples [00:00, 1174005.84 examples/s]
# Generating validation split: 1838 examples [00:00, 639921.20 examples/s]
# Generating test split: 3084 examples [00:00, 757642.68 examples/s]
# Downloading readme: 11.2kB [00:00, 41.4MB/s]
# Downloading data: 100% 2.06M/2.06M [00:00<00:00, 15.2MB/s]
# Downloading data: 100% 118k/118k [00:00<00:00, 942kB/s]
# Downloading data: 100% 85.9k/85.9k [00:00<00:00, 725kB/s]
# Generating train split: 100% 40398/40398 [00:00<00:00, 1832077.21 examples/s]
# Generating test split: 100% 1767/1767 [00:00<00:00, 773868.14 examples/s]
# Generating validation split: 100% 1267/1267 [00:00<00:00, 616709.20 examples/s]
# WARNING:lm_eval.api.task:[Task: boolq] metric acc is defined, but aggregation is not. using default aggregation=mean
# WARNING:lm_eval.api.task:[Task: boolq] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# Downloading readme: 19.7kB [00:00, 53.7MB/s]
# Downloading data: 100% 3.85M/3.85M [00:00<00:00, 27.5MB/s]
# Downloading data: 100% 1.31M/1.31M [00:00<00:00, 10.5MB/s]
# Downloading data: 100% 1.31M/1.31M [00:00<00:00, 10.3MB/s]
# Generating train split: 100% 9427/9427 [00:00<00:00, 337998.19 examples/s]
# Generating validation split: 100% 3270/3270 [00:00<00:00, 287022.58 examples/s]
# Generating test split: 100% 3245/3245 [00:00<00:00, 259381.33 examples/s]
# WARNING:lm_eval.api.task:[Task: rte] metric acc is defined, but aggregation is not. using default aggregation=mean
# WARNING:lm_eval.api.task:[Task: rte] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# Downloading readme: 35.3kB [00:00, 69.0MB/s]
# Downloading data: 100% 584k/584k [00:00<00:00, 7.99MB/s]
# Downloading data: 100% 69.0k/69.0k [00:00<00:00, 1.06MB/s]
# Downloading data: 100% 621k/621k [00:00<00:00, 8.37MB/s]
# Generating train split: 100% 2490/2490 [00:00<00:00, 472485.39 examples/s]
# Generating validation split: 100% 277/277 [00:00<00:00, 143205.01 examples/s]
# Generating test split: 100% 3000/3000 [00:00<00:00, 580901.71 examples/s]
# Downloading readme: 9.06kB [00:00, 34.1MB/s]
# Downloading data: 100% 496k/496k [00:00<00:00, 4.10MB/s]
# Downloading data: 100% 58.2k/58.2k [00:00<00:00, 475kB/s]
# Downloading data: 100% 55.5k/55.5k [00:00<00:00, 437kB/s]
# Generating train split: 100% 4957/4957 [00:00<00:00, 762251.24 examples/s]
# Generating validation split: 100% 500/500 [00:00<00:00, 220985.46 examples/s]
# Generating test split: 100% 500/500 [00:00<00:00, 228423.05 examples/s]
# Downloading readme: 5.47kB [00:00, 25.5MB/s]
# Downloading data: 100% 1.16M/1.16M [00:00<00:00, 14.8MB/s]
# Generating test split: 100% 5153/5153 [00:00<00:00, 507222.28 examples/s]
# 100% 5153/5153 [00:09<00:00, 559.14it/s]
# 100% 500/500 [00:00<00:00, 1959.03it/s]
# 100% 277/277 [00:00<00:00, 1832.04it/s]
# 100% 3270/3270 [00:01<00:00, 1840.28it/s]
# 100% 1267/1267 [00:00<00:00, 107246.74it/s]
# 100% 1838/1838 [00:01<00:00, 1029.36it/s]
# 100% 10042/10042 [00:04<00:00, 2187.89it/s]
# 100% 1172/1172 [00:01<00:00, 1020.79it/s]
# 100% 2376/2376 [00:02<00:00, 1062.29it/s]
# Running loglikelihood requests:   0% 0/74813 [00:00<?, ?it/s]Passed argument batch_size = auto:1. Detecting largest batch size
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# Determined largest batch size: 32
# Running loglikelihood requests: 100% 74813/74813 [08:09<00:00, 152.73it/s]
# bootstrapping for stddev: perplexity
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 100% 100/100 [00:08<00:00, 11.45it/s]
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: tungserver99 (tunjob) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.26.1
# wandb: Run data is saved locally in /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/smart-flip/wandb/run-20260519_150254-v375jixf
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run gptq_raw_eval_Mistral-7B-v0.3
# wandb: ⭐️ View project at https://wandb.ai/tunjob/egbc
# wandb: 🚀 View run at https://wandb.ai/tunjob/egbc/runs/v375jixf
# wandb: ⢿ updating run metadata (0.6s)
# wandb: ⣻ updating run metadata (0.6s)
# wandb: ⣽ updating run metadata (0.6s)
# wandb: ⣾ updating run metadata (0.6s)
# wandb: ⣷ uploading history steps 0-0, summary (0.1s)
# wandb:
# wandb: Run history:
# wandb:  lm_eval/arc_challenge ▁
# wandb:       lm_eval/arc_easy ▁
# wandb:          lm_eval/boolq ▁
# wandb:      lm_eval/hellaswag ▁
# wandb: lm_eval/lambada_openai ▁
# wandb:     lm_eval/openbookqa ▁
# wandb:           lm_eval/piqa ▁
# wandb:            lm_eval/rte ▁
# wandb:     lm_eval/winogrande ▁
# wandb:          perplexity/C4 ▁
# wandb:                     +1 ...
# wandb:
# wandb: Run summary:
# wandb:  lm_eval/arc_challenge 0.43942
# wandb:       lm_eval/arc_easy 0.74411
# wandb:          lm_eval/boolq 0.77584
# wandb:      lm_eval/hellaswag 0.56941
# wandb: lm_eval/lambada_openai 0.69396
# wandb:     lm_eval/openbookqa 0.294
# wandb:           lm_eval/piqa 0.78183
# wandb:            lm_eval/rte 0.57762
# wandb:     lm_eval/winogrande 0.69534
# wandb:             model_slug gptq_raw_Mistral-7B-...
# wandb:                     +4 ...
# wandb:
# wandb: 🚀 View run gptq_raw_eval_Mistral-7B-v0.3 at: https://wandb.ai/tunjob/egbc/runs/v375jixf
# wandb: ⭐️ View project at: https://wandb.ai/tunjob/egbc
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260519_150254-v375jixf/logs
#
# Saved evaluation results to results/eval/gptq_raw_eval_Mistral-7B-v0.3.json
# ==> smart_flip from raw :: bits=3 :: knee=0.0 :: max_flip=0.05
# Loading checkpoint shards: 100% 3/3 [00:01<00:00,  1.52it/s]
#
# [GPTQ Quantizer Initialized]
#   Config: GPTQConfig(bits=3, group_size=128, percdamp=0.01, sym=True, act_order=False, true_sequential=True, static_groups=False, mse=False, max_bias_samples=4096)
#   Post correction: SmartFlipCorrection
#
# Saved gptq_smart_flip model to results/models/gptq_smart_flip/gptq_smart_flip_Mistral-7B-v0.3_from_raw_b3_k0.0_f0.05
#
# Evaluating smart_flip_quantize on WikiText-2...
# Loading checkpoint shards: 100% 3/3 [00:13<00:00,  4.40s/it]
#
# Evaluating smart_flip_quantize on C4...
# Loading checkpoint shards: 100% 3/3 [00:12<00:00,  4.00s/it]
#
# Running lm-eval for smart_flip_quantize on arc_easy, arc_challenge, hellaswag, piqa, winogrande, boolq, rte, openbookqa, lambada_openai...
# 2026-05-19 15:44:00.830725: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-19 15:44:02.016161: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading checkpoint shards: 100% 3/3 [00:12<00:00,  4.14s/it]
# WARNING:lm_eval.api.task:[Task: boolq] metric acc is defined, but aggregation is not. using default aggregation=mean
# WARNING:lm_eval.api.task:[Task: boolq] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# WARNING:lm_eval.api.task:[Task: rte] metric acc is defined, but aggregation is not. using default aggregation=mean
# WARNING:lm_eval.api.task:[Task: rte] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# 100% 5153/5153 [00:09<00:00, 561.46it/s]
# 100% 500/500 [00:00<00:00, 1981.71it/s]
# 100% 277/277 [00:00<00:00, 1790.09it/s]
# 100% 3270/3270 [00:02<00:00, 1494.28it/s]
# 100% 1267/1267 [00:00<00:00, 107720.66it/s]
# 100% 1838/1838 [00:01<00:00, 1016.50it/s]
# 100% 10042/10042 [00:04<00:00, 2416.53it/s]
# 100% 1172/1172 [00:01<00:00, 1043.30it/s]
# 100% 2376/2376 [00:02<00:00, 1058.90it/s]
# Running loglikelihood requests:   0% 0/74813 [00:00<?, ?it/s]Passed argument batch_size = auto:1. Detecting largest batch size
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# Determined largest batch size: 32
# Running loglikelihood requests: 100% 74813/74813 [08:12<00:00, 152.05it/s]
# bootstrapping for stddev: perplexity
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 100% 100/100 [00:08<00:00, 11.61it/s]
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: tungserver99 (tunjob) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.26.1
# wandb: Run data is saved locally in /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/smart-flip/wandb/run-20260519_155420-4uqbp1u7
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run gptq_smart_flip_Mistral-7B-v0.3_from_raw_b3_k0.0_f0.05
# wandb: ⭐️ View project at https://wandb.ai/tunjob/egbc
# wandb: 🚀 View run at https://wandb.ai/tunjob/egbc/runs/4uqbp1u7
# wandb: ⢿ updating run metadata (0.6s)
# wandb: ⣻ updating run metadata (0.6s)
# wandb: ⣽ updating run metadata (0.6s)
# wandb: ⣾ updating run metadata (0.6s)
# wandb:
# wandb: Run history:
# wandb:  lm_eval/arc_challenge ▁
# wandb:       lm_eval/arc_easy ▁
# wandb:          lm_eval/boolq ▁
# wandb:      lm_eval/hellaswag ▁
# wandb: lm_eval/lambada_openai ▁
# wandb:     lm_eval/openbookqa ▁
# wandb:           lm_eval/piqa ▁
# wandb:            lm_eval/rte ▁
# wandb:     lm_eval/winogrande ▁
# wandb:          perplexity/C4 ▁
# wandb:                     +1 ...
# wandb:
# wandb: Run summary:
# wandb:  lm_eval/arc_challenge 0.45392
# wandb:       lm_eval/arc_easy 0.77357
# wandb:          lm_eval/boolq 0.80795
# wandb:      lm_eval/hellaswag 0.58903
# wandb: lm_eval/lambada_openai 0.70871
# wandb:     lm_eval/openbookqa 0.332
# wandb:           lm_eval/piqa 0.78999
# wandb:            lm_eval/rte 0.67148
# wandb:     lm_eval/winogrande 0.71113
# wandb:             model_slug Mistral-7B-v0.3
# wandb:                     +4 ...
# wandb:
# wandb: 🚀 View run gptq_smart_flip_Mistral-7B-v0.3_from_raw_b3_k0.0_f0.05 at: https://wandb.ai/tunjob/egbc/runs/4uqbp1u7
# wandb: ⭐️ View project at: https://wandb.ai/tunjob/egbc
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260519_155420-4uqbp1u7/logs
#
# Saved evaluation results to results/eval/gptq_smart_flip_Mistral-7B-v0.3_from_raw_b3_k0.0_f0.05.json

# %%
# !RUN_FLOAT_MODEL=0 ./scripts/bash/smart_flip/gptq/run_llama31.sh
# Out:
# ==> skipping float_model :: meta-llama/Llama-3.1-8B
# ==> raw_quantize :: meta-llama/Llama-3.1-8B :: origin=gptq
# tokenizer_config.json: 50.5kB [00:00, 114MB/s]
# tokenizer.json: 9.09MB [00:00, 37.7MB/s]
# special_tokens_map.json: 100% 73.0/73.0 [00:00<00:00, 653kB/s]
# config.json: 100% 826/826 [00:00<00:00, 8.79MB/s]
# model.safetensors.index.json: 23.9kB [00:00, 22.4MB/s]
# Downloading shards:   0% 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0% 0.00/4.98G [00:01<?, ?B/s]
# model-00001-of-00004.safetensors:   1% 67.0M/4.98G [00:01<00:14, 335MB/s]
# model-00001-of-00004.safetensors:   3% 134M/4.98G [00:01<00:22, 211MB/s]
# model-00001-of-00004.safetensors:   5% 268M/4.98G [00:01<00:12, 370MB/s]
# model-00001-of-00004.safetensors:   7% 335M/4.98G [00:02<00:12, 359MB/s]
# model-00001-of-00004.safetensors:   9% 469M/4.98G [00:02<00:09, 459MB/s]
# model-00001-of-00004.safetensors:  11% 537M/4.98G [00:02<00:10, 420MB/s]
# model-00001-of-00004.safetensors:  19% 939M/4.98G [00:02<00:05, 697MB/s]
# model-00001-of-00004.safetensors:  21% 1.02G/4.98G [00:03<00:06, 629MB/s]
# model-00001-of-00004.safetensors:  25% 1.22G/4.98G [00:03<00:07, 476MB/s]
# model-00001-of-00004.safetensors:  30% 1.49G/4.98G [00:03<00:05, 648MB/s]
# model-00001-of-00004.safetensors:  36% 1.78G/4.98G [00:04<00:04, 672MB/s]
# model-00001-of-00004.safetensors:  41% 2.04G/4.98G [00:06<00:11, 263MB/s]
# model-00001-of-00004.safetensors:  52% 2.59G/4.98G [00:06<00:05, 443MB/s]
# model-00001-of-00004.safetensors:  77% 3.83G/4.98G [00:10<00:03, 350MB/s]
# model-00001-of-00004.safetensors: 100% 4.98G/4.98G [00:12<00:00, 401MB/s]
# Downloading shards:  25% 1/4 [00:12<00:37, 12.57s/it]
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0% 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   1% 67.1M/5.00G [00:01<00:14, 336MB/s]
# model-00002-of-00004.safetensors:   3% 134M/5.00G [00:01<00:14, 332MB/s]
# model-00002-of-00004.safetensors:   4% 201M/5.00G [00:01<00:14, 336MB/s]
# model-00002-of-00004.safetensors:   5% 268M/5.00G [00:01<00:14, 336MB/s]
# model-00002-of-00004.safetensors:  11% 536M/5.00G [00:02<00:11, 406MB/s]
# model-00002-of-00004.safetensors:  15% 768M/5.00G [00:02<00:07, 579MB/s]
# model-00002-of-00004.safetensors:  20% 1.02G/5.00G [00:03<00:07, 503MB/s]
# model-00002-of-00004.safetensors:  24% 1.21G/5.00G [00:03<00:06, 582MB/s]
# model-00002-of-00004.safetensors:  28% 1.41G/5.00G [00:03<00:06, 554MB/s]
# model-00002-of-00004.safetensors:  30% 1.48G/5.00G [00:03<00:06, 510MB/s]
# model-00002-of-00004.safetensors:  34% 1.68G/5.00G [00:04<00:10, 328MB/s]
# model-00002-of-00004.safetensors:  62% 3.08G/5.00G [00:10<00:07, 249MB/s]
# model-00002-of-00004.safetensors:  83% 4.16G/5.00G [00:11<00:02, 387MB/s]
# model-00002-of-00004.safetensors: 100% 5.00G/5.00G [00:15<00:00, 329MB/s]
# Downloading shards:  50% 2/4 [00:27<00:28, 14.20s/it]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:01<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:01<?, ?B/s]
# model-00003-of-00004.safetensors:   0% 0.00/4.92G [00:01<?, ?B/s]
# model-00003-of-00004.safetensors:   7% 335M/4.92G [00:01<00:02, 1.68GB/s]
# model-00003-of-00004.safetensors:   8% 402M/4.92G [00:01<00:05, 888MB/s]
# model-00003-of-00004.safetensors:  11% 536M/4.92G [00:02<00:08, 541MB/s]
# model-00003-of-00004.safetensors:  19% 939M/4.92G [00:03<00:10, 391MB/s]
# model-00003-of-00004.safetensors:  26% 1.27G/4.92G [00:03<00:06, 581MB/s]
# model-00003-of-00004.safetensors:  41% 2.01G/4.92G [00:05<00:05, 544MB/s]
# model-00003-of-00004.safetensors:  74% 3.62G/4.92G [00:11<00:04, 304MB/s]
# model-00003-of-00004.safetensors:  91% 4.49G/4.92G [00:12<00:01, 401MB/s]
# model-00003-of-00004.safetensors: 100% 4.92G/4.92G [00:13<00:00, 378MB/s]
# Downloading shards:  75% 3/4 [00:41<00:13, 13.70s/it]
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:01<?, ?B/s]
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:01<?, ?B/s]
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:01<?, ?B/s]
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:01<?, ?B/s]
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:01<?, ?B/s]
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:02<?, ?B/s]
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:02<?, ?B/s]
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:02<?, ?B/s]
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:02<?, ?B/s]
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:02<?, ?B/s]
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:03<?, ?B/s]
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:03<?, ?B/s]
# model-00004-of-00004.safetensors:   0% 0.00/1.17G [00:03<?, ?B/s]
# model-00004-of-00004.safetensors:  22% 256M/1.17G [00:03<00:00, 1.28GB/s]
# model-00004-of-00004.safetensors: 100% 1.17G/1.17G [00:04<00:00, 265MB/s]
# Downloading shards: 100% 4/4 [00:45<00:00, 11.39s/it]
# Loading checkpoint shards: 100% 4/4 [00:00<00:00,  6.66it/s]
# generation_config.json: 100% 185/185 [00:00<00:00, 1.75MB/s]
#
# [C4 Calibration Data - Optimized]
#   Samples: 128
#   Sequence length: 2048 tokens
#   Seed: 42
#   Collected 128 samples from C4
#   Skipped 4181 documents
#
# [GPTQ Quantizer Initialized]
#   Config: GPTQConfig(bits=3, group_size=-1, percdamp=0.01, sym=False, act_order=True, true_sequential=True, static_groups=False, mse=False, max_bias_samples=4096)
#   Post correction: none
#
# ================================================================================
# GPTQ Sequential Quantization
# ================================================================================
#
# [Layer 1/32]
#   Quantizing self_attn.k_proj
# time 2.61
# error 10288.8681640625
#   Quantizing self_attn.v_proj
# time 2.05
# error 228.0568389892578
#   Quantizing self_attn.q_proj
# time 2.06
# error 16482.607421875
#   Quantizing self_attn.o_proj
# time 2.26
# error 10.339624404907227
#   Quantizing mlp.up_proj
# time 2.18
# error 8625.1123046875
#   Quantizing mlp.gate_proj
# time 2.08
# error 11090.0654296875
#   Quantizing mlp.down_proj
# time 8.15
# error 61.47037887573242
#
# [Layer 2/32]
#   Quantizing self_attn.k_proj
# time 2.03
# error 8139.02001953125
#   Quantizing self_attn.v_proj
# time 2.06
# error 466.59368896484375
#   Quantizing self_attn.q_proj
# time 2.04
# error 14602.560546875
#   Quantizing self_attn.o_proj
# time 2.11
# error 32.64731216430664
#   Quantizing mlp.up_proj
# time 2.27
# error 17172.19921875
#   Quantizing mlp.gate_proj
# time 2.21
# error 20602.03125
#   Quantizing mlp.down_proj
# time 7.59
# error 347.41485595703125
#
# [Layer 3/32]
#   Quantizing self_attn.k_proj
# time 2.28
# error 53720.125
#   Quantizing self_attn.v_proj
# time 2.28
# error 2504.467529296875
#   Quantizing self_attn.q_proj
# time 2.03
# error 84758.140625
#   Quantizing self_attn.o_proj
# time 2.06
# error 40.42369842529297
#   Quantizing mlp.up_proj
# time 2.08
# error 28482.724609375
#   Quantizing mlp.gate_proj
# time 2.18
# error 36265.1875
#   Quantizing mlp.down_proj
# time 7.72
# error 293.5513610839844
#
# [Layer 4/32]
#   Quantizing self_attn.k_proj
# time 2.02
# error 43975.25390625
#   Quantizing self_attn.v_proj
# time 2.02
# error 3820.6025390625
#   Quantizing self_attn.q_proj
# time 2.05
# error 78415.8515625
#   Quantizing self_attn.o_proj
# time 2.08
# error 95.28837585449219
#   Quantizing mlp.up_proj
# time 2.18
# error 37935.16796875
#   Quantizing mlp.gate_proj
# time 2.04
# error 54951.7890625
#   Quantizing mlp.down_proj
# time 7.75
# error 483.25152587890625
#
# [Layer 5/32]
#   Quantizing self_attn.k_proj
# time 2.04
# error 40806.4375
#   Quantizing self_attn.v_proj
# time 2.04
# error 3735.518310546875
#   Quantizing self_attn.q_proj
# time 2.05
# error 70461.515625
#   Quantizing self_attn.o_proj
# time 2.05
# error 170.29185485839844
#   Quantizing mlp.up_proj
# time 2.07
# error 50588.1953125
#   Quantizing mlp.gate_proj
# time 2.08
# error 81662.3515625
#   Quantizing mlp.down_proj
# time 8.01
# error 811.308837890625
#
# [Layer 6/32]
#   Quantizing self_attn.k_proj
# time 2.06
# error 68426.171875
#   Quantizing self_attn.v_proj
# time 2.06
# error 3981.97900390625
#   Quantizing self_attn.q_proj
# time 2.09
# error 106294.2890625
#   Quantizing self_attn.o_proj
# time 2.09
# error 196.91973876953125
#   Quantizing mlp.up_proj
# time 2.07
# error 60538.82421875
#   Quantizing mlp.gate_proj
# time 2.07
# error 97884.8046875
#   Quantizing mlp.down_proj
# time 7.76
# error 1163.8111572265625
#
# [Layer 7/32]
#   Quantizing self_attn.k_proj
# time 2.04
# error 52847.109375
#   Quantizing self_attn.v_proj
# time 2.05
# error 4221.17431640625
#   Quantizing self_attn.q_proj
# time 2.06
# error 93783.25
#   Quantizing self_attn.o_proj
# time 2.07
# error 334.8459167480469
#   Quantizing mlp.up_proj
# time 2.09
# error 66139.9609375
#   Quantizing mlp.gate_proj
# time 2.09
# error 108710.3359375
#   Quantizing mlp.down_proj
# time 7.85
# error 1368.389404296875
#
# [Layer 8/32]
#   Quantizing self_attn.k_proj
# time 2.41
# error 52743.3359375
#   Quantizing self_attn.v_proj
# time 2.06
# error 4376.98046875
#   Quantizing self_attn.q_proj
# time 2.05
# error 89589.515625
#   Quantizing self_attn.o_proj
# time 2.19
# error 474.5046081542969
#   Quantizing mlp.up_proj
# time 2.16
# error 72696.078125
#   Quantizing mlp.gate_proj
# time 2.08
# error 109630.0
#   Quantizing mlp.down_proj
# time 7.88
# error 1593.095458984375
#
# [Layer 9/32]
#   Quantizing self_attn.k_proj
# time 2.12
# error 79298.0
#   Quantizing self_attn.v_proj
# time 2.04
# error 5842.75
#   Quantizing self_attn.q_proj
# time 2.03
# error 118701.5703125
#   Quantizing self_attn.o_proj
# time 2.27
# error 623.8388671875
#   Quantizing mlp.up_proj
# time 2.08
# error 75569.1640625
#   Quantizing mlp.gate_proj
# time 2.09
# error 115927.125
#   Quantizing mlp.down_proj
# time 7.77
# error 1763.125244140625
#
# [Layer 10/32]
#   Quantizing self_attn.k_proj
# time 2.31
# error 70784.984375
#   Quantizing self_attn.v_proj
# time 2.03
# error 8070.4345703125
#   Quantizing self_attn.q_proj
# time 2.06
# error 110446.03125
#   Quantizing self_attn.o_proj
# time 2.07
# error 878.054443359375
#   Quantizing mlp.up_proj
# time 2.06
# error 78578.984375
#   Quantizing mlp.gate_proj
# time 2.09
# error 121846.5234375
#   Quantizing mlp.down_proj
# time 7.74
# error 1811.26953125
#
# [Layer 11/32]
#   Quantizing self_attn.k_proj
# time 2.11
# error 90953.453125
#   Quantizing self_attn.v_proj
# time 2.19
# error 6478.3544921875
#   Quantizing self_attn.q_proj
# time 2.06
# error 137992.5
#   Quantizing self_attn.o_proj
# time 2.19
# error 826.7958984375
#   Quantizing mlp.up_proj
# time 2.18
# error 80330.703125
#   Quantizing mlp.gate_proj
# time 2.07
# error 116578.4296875
#   Quantizing mlp.down_proj
# time 7.78
# error 1866.52685546875
#
# [Layer 12/32]
#   Quantizing self_attn.k_proj
# time 2.07
# error 76366.5
#   Quantizing self_attn.v_proj
# time 2.03
# error 6485.357421875
#   Quantizing self_attn.q_proj
# time 2.06
# error 112117.78125
#   Quantizing self_attn.o_proj
# time 2.14
# error 871.515625
#   Quantizing mlp.up_proj
# time 2.27
# error 84533.5625
#   Quantizing mlp.gate_proj
# time 2.10
# error 121051.171875
#   Quantizing mlp.down_proj
# time 7.75
# error 2110.7568359375
#
# [Layer 13/32]
#   Quantizing self_attn.k_proj
# time 2.08
# error 55215.890625
#   Quantizing self_attn.v_proj
# time 2.04
# error 7398.6162109375
#   Quantizing self_attn.q_proj
# time 2.04
# error 97198.5
#   Quantizing self_attn.o_proj
# time 2.10
# error 1027.1572265625
#   Quantizing mlp.up_proj
# time 2.09
# error 91426.1875
#   Quantizing mlp.gate_proj
# time 2.09
# error 123603.6875
#   Quantizing mlp.down_proj
# time 7.74
# error 2531.333984375
#
# [Layer 14/32]
#   Quantizing self_attn.k_proj
# time 2.05
# error 97964.78125
#   Quantizing self_attn.v_proj
# time 2.03
# error 8507.701171875
#   Quantizing self_attn.q_proj
# time 2.04
# error 126640.0390625
#   Quantizing self_attn.o_proj
# time 2.09
# error 1208.4620361328125
#   Quantizing mlp.up_proj
# time 2.08
# error 96016.15625
#   Quantizing mlp.gate_proj
# time 2.08
# error 133060.4375
#   Quantizing mlp.down_proj
# time 7.79
# error 2744.03076171875
#
# [Layer 15/32]
#   Quantizing self_attn.k_proj
# time 2.05
# error 104789.578125
#   Quantizing self_attn.v_proj
# time 2.08
# error 9463.212890625
#   Quantizing self_attn.q_proj
# time 2.07
# error 136549.796875
#   Quantizing self_attn.o_proj
# time 2.11
# error 1481.940185546875
#   Quantizing mlp.up_proj
# time 2.64
# error 105949.421875
#   Quantizing mlp.gate_proj
# time 2.10
# error 160179.0
#   Quantizing mlp.down_proj
# time 7.95
# error 3464.818603515625
#
# [Layer 16/32]
#   Quantizing self_attn.k_proj
# time 2.41
# error 91798.5
#   Quantizing self_attn.v_proj
# time 2.33
# error 12009.923828125
#   Quantizing self_attn.q_proj
# time 2.07
# error 156531.609375
#   Quantizing self_attn.o_proj
# time 2.08
# error 1999.305419921875
#   Quantizing mlp.up_proj
# time 2.09
# error 109082.984375
#   Quantizing mlp.gate_proj
# time 2.11
# error 173263.328125
#   Quantizing mlp.down_proj
# time 7.88
# error 4194.251953125
#
# [Layer 17/32]
#   Quantizing self_attn.k_proj
# time 2.23
# error 91282.2734375
#   Quantizing self_attn.v_proj
# time 2.04
# error 11164.0048828125
#   Quantizing self_attn.q_proj
# time 2.05
# error 143078.03125
#   Quantizing self_attn.o_proj
# time 2.13
# error 1412.459228515625
#   Quantizing mlp.up_proj
# time 2.17
# error 115242.5625
#   Quantizing mlp.gate_proj
# time 2.12
# error 189183.25
#   Quantizing mlp.down_proj
# time 7.81
# error 4597.30712890625
#
# [Layer 18/32]
#   Quantizing self_attn.k_proj
# time 2.10
# error 100402.265625
#   Quantizing self_attn.v_proj
# time 2.03
# error 10570.9716796875
#   Quantizing self_attn.q_proj
# time 2.06
# error 143860.65625
#   Quantizing self_attn.o_proj
# time 2.12
# error 1577.364013671875
#   Quantizing mlp.up_proj
# time 2.15
# error 120088.375
#   Quantizing mlp.gate_proj
# time 2.18
# error 201090.171875
#   Quantizing mlp.down_proj
# time 7.76
# error 5430.17138671875
#
# [Layer 19/32]
#   Quantizing self_attn.k_proj
# time 2.01
# error 108236.125
#   Quantizing self_attn.v_proj
# time 2.05
# error 12576.91796875
#   Quantizing self_attn.q_proj
# time 2.06
# error 144580.203125
#   Quantizing self_attn.o_proj
# time 2.10
# error 948.1373291015625
#   Quantizing mlp.up_proj
# time 2.06
# error 123788.84375
#   Quantizing mlp.gate_proj
# time 2.06
# error 206167.34375
#   Quantizing mlp.down_proj
# time 7.73
# error 5302.31396484375
#
# [Layer 20/32]
#   Quantizing self_attn.k_proj
# time 2.05
# error 95646.65625
#   Quantizing self_attn.v_proj
# time 2.04
# error 12787.583984375
#   Quantizing self_attn.q_proj
# time 2.12
# error 147388.046875
#   Quantizing self_attn.o_proj
# time 2.38
# error 853.7857055664062
#   Quantizing mlp.up_proj
# time 2.08
# error 128252.0546875
#   Quantizing mlp.gate_proj
# time 2.07
# error 217053.71875
#   Quantizing mlp.down_proj
# time 7.87
# error 5721.494140625
#
# [Layer 21/32]
#   Quantizing self_attn.k_proj
# time 2.05
# error 107042.90625
#   Quantizing self_attn.v_proj
# time 2.03
# error 13309.1884765625
#   Quantizing self_attn.q_proj
# time 2.04
# error 150357.015625
#   Quantizing self_attn.o_proj
# time 2.48
# error 975.1119384765625
#   Quantizing mlp.up_proj
# time 2.12
# error 134937.96875
#   Quantizing mlp.gate_proj
# time 2.09
# error 225934.9375
#   Quantizing mlp.down_proj
# time 7.74
# error 6152.865234375
#
# [Layer 22/32]
#   Quantizing self_attn.k_proj
# time 2.45
# error 99859.6953125
#   Quantizing self_attn.v_proj
# time 2.04
# error 14896.9921875
#   Quantizing self_attn.q_proj
# time 2.07
# error 141415.484375
#   Quantizing self_attn.o_proj
# time 2.15
# error 1359.39892578125
#   Quantizing mlp.up_proj
# time 2.09
# error 142760.3125
#   Quantizing mlp.gate_proj
# time 2.06
# error 241786.1875
#   Quantizing mlp.down_proj
# time 7.90
# error 7328.3408203125
#
# [Layer 23/32]
#   Quantizing self_attn.k_proj
# time 2.08
# error 104795.140625
#   Quantizing self_attn.v_proj
# time 2.10
# error 16185.7939453125
#   Quantizing self_attn.q_proj
# time 2.06
# error 140900.375
#   Quantizing self_attn.o_proj
# time 2.18
# error 1105.50634765625
#   Quantizing mlp.up_proj
# time 2.09
# error 146624.828125
#   Quantizing mlp.gate_proj
# time 2.07
# error 244136.21875
#   Quantizing mlp.down_proj
# time 7.74
# error 7305.23046875
#
# [Layer 24/32]
#   Quantizing self_attn.k_proj
# time 2.21
# error 108749.1484375
#   Quantizing self_attn.v_proj
# time 2.12
# error 17253.203125
#   Quantizing self_attn.q_proj
# time 2.06
# error 150331.078125
#   Quantizing self_attn.o_proj
# time 2.30
# error 1064.6968994140625
#   Quantizing mlp.up_proj
# time 2.20
# error 153067.671875
#   Quantizing mlp.gate_proj
# time 2.06
# error 253009.0
#   Quantizing mlp.down_proj
# time 7.79
# error 7689.9853515625
#
# [Layer 25/32]
#   Quantizing self_attn.k_proj
# time 2.16
# error 107724.5
#   Quantizing self_attn.v_proj
# time 2.20
# error 22972.0078125
#   Quantizing self_attn.q_proj
# time 2.04
# error 151473.875
#   Quantizing self_attn.o_proj
# time 2.32
# error 1309.706298828125
#   Quantizing mlp.up_proj
# time 2.10
# error 162414.359375
#   Quantizing mlp.gate_proj
# time 2.14
# error 268017.90625
#   Quantizing mlp.down_proj
# time 7.85
# error 8020.87353515625
#
# [Layer 26/32]
#   Quantizing self_attn.k_proj
# time 2.09
# error 101867.6796875
#   Quantizing self_attn.v_proj
# time 2.04
# error 24204.28125
#   Quantizing self_attn.q_proj
# time 2.06
# error 154005.921875
#   Quantizing self_attn.o_proj
# time 2.34
# error 1622.4464111328125
#   Quantizing mlp.up_proj
# time 2.08
# error 170000.015625
#   Quantizing mlp.gate_proj
# time 2.08
# error 279446.25
#   Quantizing mlp.down_proj
# time 7.77
# error 8664.8203125
#
# [Layer 27/32]
#   Quantizing self_attn.k_proj
# time 2.05
# error 104766.734375
#   Quantizing self_attn.v_proj
# time 2.04
# error 21207.2265625
#   Quantizing self_attn.q_proj
# time 2.05
# error 148258.34375
#   Quantizing self_attn.o_proj
# time 2.08
# error 1681.153564453125
#   Quantizing mlp.up_proj
# time 2.14
# error 179400.96875
#   Quantizing mlp.gate_proj
# time 2.10
# error 298506.3125
#   Quantizing mlp.down_proj
# time 7.83
# error 9622.328125
#
# [Layer 28/32]
#   Quantizing self_attn.k_proj
# time 2.07
# error 119938.3359375
#   Quantizing self_attn.v_proj
# time 2.05
# error 33488.84765625
#   Quantizing self_attn.q_proj
# time 2.06
# error 157454.59375
#   Quantizing self_attn.o_proj
# time 2.11
# error 2034.349853515625
#   Quantizing mlp.up_proj
# time 2.12
# error 196633.96875
#   Quantizing mlp.gate_proj
# time 2.20
# error 324461.21875
#   Quantizing mlp.down_proj
# time 7.74
# error 11450.98046875
#
# [Layer 29/32]
#   Quantizing self_attn.k_proj
# time 2.37
# error 95433.84375
#   Quantizing self_attn.v_proj
# time 2.04
# error 27366.095703125
#   Quantizing self_attn.q_proj
# time 2.05
# error 145200.90625
#   Quantizing self_attn.o_proj
# time 2.16
# error 3521.69921875
#   Quantizing mlp.up_proj
# time 2.12
# error 218101.953125
#   Quantizing mlp.gate_proj
# time 2.09
# error 347085.4375
#   Quantizing mlp.down_proj
# time 7.74
# error 15479.65625
#
# [Layer 30/32]
#   Quantizing self_attn.k_proj
# time 2.05
# error 101230.5625
#   Quantizing self_attn.v_proj
# time 2.05
# error 35610.0625
#   Quantizing self_attn.q_proj
# time 2.12
# error 167895.21875
#   Quantizing self_attn.o_proj
# time 2.20
# error 2976.3662109375
#   Quantizing mlp.up_proj
# time 2.09
# error 233288.21875
#   Quantizing mlp.gate_proj
# time 2.09
# error 358628.0
#   Quantizing mlp.down_proj
# time 7.94
# error 23294.88671875
#
# [Layer 31/32]
#   Quantizing self_attn.k_proj
# time 2.09
# error 117809.5546875
#   Quantizing self_attn.v_proj
# time 2.09
# error 47933.421875
#   Quantizing self_attn.q_proj
# time 2.11
# error 153959.15625
#   Quantizing self_attn.o_proj
# time 2.34
# error 5386.5732421875
#   Quantizing mlp.up_proj
# time 2.13
# error 250886.234375
#   Quantizing mlp.gate_proj
# time 2.13
# error 387090.53125
#   Quantizing mlp.down_proj
# time 7.80
# error 45314.4140625
#
# [Layer 32/32]
#   Quantizing self_attn.k_proj
# time 2.15
# error 81861.7890625
#   Quantizing self_attn.v_proj
# time 2.06
# error 29295.8359375
#   Quantizing self_attn.q_proj
# time 2.06
# error 142700.5
#   Quantizing self_attn.o_proj
# time 2.18
# error 12617.763671875
#   Quantizing mlp.up_proj
# time 2.09
# error 252595.90625
#   Quantizing mlp.gate_proj
# time 2.06
# error 351418.875
#   Quantizing mlp.down_proj
# time 7.79
# error 154885.828125
#
# ================================================================================
# GPTQ Quantization Complete
# ================================================================================
#
# Saved gptq_raw model to results/models/gptq_raw/gptq_raw_Llama-3.1-8B
#
# Evaluating raw_quantize on WikiText-2...
# Loading checkpoint shards: 100% 4/4 [00:15<00:00,  3.87s/it]
# Token indices sequence length is longer than the specified maximum sequence length for this model (288936 > 131072). Running this sequence through the model will result in indexing errors
#
# Evaluating raw_quantize on C4...
# Loading checkpoint shards: 100% 4/4 [00:13<00:00,  3.34s/it]
# Token indices sequence length is longer than the specified maximum sequence length for this model (291380 > 131072). Running this sequence through the model will result in indexing errors
#
# Running lm-eval for raw_quantize on arc_easy, arc_challenge, hellaswag, piqa, winogrande, boolq, rte, openbookqa, lambada_openai...
# 2026-05-19 17:04:23.087539: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-19 17:04:24.258385: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading checkpoint shards: 100% 4/4 [00:14<00:00,  3.52s/it]
# WARNING:lm_eval.api.task:[Task: boolq] metric acc is defined, but aggregation is not. using default aggregation=mean
# WARNING:lm_eval.api.task:[Task: boolq] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# WARNING:lm_eval.api.task:[Task: rte] metric acc is defined, but aggregation is not. using default aggregation=mean
# WARNING:lm_eval.api.task:[Task: rte] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# 100% 5153/5153 [00:09<00:00, 560.18it/s]
# 100% 500/500 [00:00<00:00, 1979.27it/s]
# 100% 277/277 [00:00<00:00, 1819.30it/s]
# 100% 3270/3270 [00:02<00:00, 1481.88it/s]
# 100% 1267/1267 [00:00<00:00, 111403.78it/s]
# 100% 1838/1838 [00:01<00:00, 1021.27it/s]
# 100% 10042/10042 [00:04<00:00, 2395.89it/s]
# 100% 1172/1172 [00:01<00:00, 1046.42it/s]
# 100% 2376/2376 [00:02<00:00, 1053.67it/s]
# Running loglikelihood requests:   0% 0/74813 [00:00<?, ?it/s]Passed argument batch_size = auto:1. Detecting largest batch size
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# Determined largest batch size: 11
# Running loglikelihood requests: 100% 74813/74813 [08:43<00:00, 142.79it/s]
# bootstrapping for stddev: perplexity
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 100% 100/100 [00:08<00:00, 11.85it/s]
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: tungserver99 (tunjob) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.26.1
# wandb: Run data is saved locally in /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/smart-flip/wandb/run-20260519_171521-hspjo1q3
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run gptq_raw_Llama-3.1-8B
# wandb: ⭐️ View project at https://wandb.ai/tunjob/egbc
# wandb: 🚀 View run at https://wandb.ai/tunjob/egbc/runs/hspjo1q3
# wandb: ⢿ updating run metadata (0.6s)
# wandb: ⣻ updating run metadata (0.6s)
# wandb: ⣽ updating run metadata (0.6s)
# wandb: ⣾ updating run metadata (0.6s)
# wandb:
# wandb: Run history:
# wandb:  lm_eval/arc_challenge ▁
# wandb:       lm_eval/arc_easy ▁
# wandb:          lm_eval/boolq ▁
# wandb:      lm_eval/hellaswag ▁
# wandb: lm_eval/lambada_openai ▁
# wandb:     lm_eval/openbookqa ▁
# wandb:           lm_eval/piqa ▁
# wandb:            lm_eval/rte ▁
# wandb:     lm_eval/winogrande ▁
# wandb:          perplexity/C4 ▁
# wandb:                     +1 ...
# wandb:
# wandb: Run summary:
# wandb:  lm_eval/arc_challenge 0.30546
# wandb:       lm_eval/arc_easy 0.61532
# wandb:          lm_eval/boolq 0.63761
# wandb:      lm_eval/hellaswag 0.429
# wandb: lm_eval/lambada_openai 0.46594
# wandb:     lm_eval/openbookqa 0.214
# wandb:           lm_eval/piqa 0.7062
# wandb:            lm_eval/rte 0.54874
# wandb:     lm_eval/winogrande 0.62273
# wandb:             model_slug Llama-3p1-8B
# wandb:                     +4 ...
# wandb:
# wandb: 🚀 View run gptq_raw_Llama-3.1-8B at: https://wandb.ai/tunjob/egbc/runs/hspjo1q3
# wandb: ⭐️ View project at: https://wandb.ai/tunjob/egbc
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260519_171521-hspjo1q3/logs
#
# Saved evaluation results to results/eval/gptq_raw_Llama-3.1-8B.json
# ==> smart_flip :: meta-llama/Llama-3.1-8B :: origin=gptq :: bits=3 :: knee=0.0 :: max_flip=0.05
# Loading checkpoint shards: 100% 4/4 [00:02<00:00,  1.77it/s]
#
# [GPTQ Quantizer Initialized]
#   Config: GPTQConfig(bits=3, group_size=-1, percdamp=0.01, sym=False, act_order=True, true_sequential=True, static_groups=False, mse=False, max_bias_samples=4096)
#   Post correction: SmartFlipCorrection
#
# Saved gptq_smart_flip model to results/models/gptq_smart_flip/gptq_smart_flip_Llama-3.1-8B_b3_k0.0_f0.05
#
# Evaluating smart_flip_quantize on WikiText-2...
# Loading checkpoint shards: 100% 4/4 [00:15<00:00,  3.83s/it]
# Token indices sequence length is longer than the specified maximum sequence length for this model (288936 > 131072). Running this sequence through the model will result in indexing errors
#
# Evaluating smart_flip_quantize on C4...
# Loading checkpoint shards: 100% 4/4 [00:13<00:00,  3.28s/it]
# Token indices sequence length is longer than the specified maximum sequence length for this model (291380 > 131072). Running this sequence through the model will result in indexing errors
#
# Running lm-eval for smart_flip_quantize on arc_easy, arc_challenge, hellaswag, piqa, winogrande, boolq, rte, openbookqa, lambada_openai...
# 2026-05-19 17:50:22.840159: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-19 17:50:24.049372: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading checkpoint shards: 100% 4/4 [00:13<00:00,  3.49s/it]
# WARNING:lm_eval.api.task:[Task: boolq] metric acc is defined, but aggregation is not. using default aggregation=mean
# WARNING:lm_eval.api.task:[Task: boolq] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# WARNING:lm_eval.api.task:[Task: rte] metric acc is defined, but aggregation is not. using default aggregation=mean
# WARNING:lm_eval.api.task:[Task: rte] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# 100% 5153/5153 [00:09<00:00, 560.48it/s]
# 100% 500/500 [00:00<00:00, 1954.88it/s]
# 100% 277/277 [00:00<00:00, 1787.17it/s]
# 100% 3270/3270 [00:02<00:00, 1484.70it/s]
# 100% 1267/1267 [00:00<00:00, 108995.47it/s]
# 100% 1838/1838 [00:01<00:00, 1013.13it/s]
# 100% 10042/10042 [00:04<00:00, 2411.64it/s]
# 100% 1172/1172 [00:01<00:00, 1046.40it/s]
# 100% 2376/2376 [00:02<00:00, 1055.68it/s]
# Running loglikelihood requests:   0% 0/74813 [00:00<?, ?it/s]Passed argument batch_size = auto:1. Detecting largest batch size
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# Determined largest batch size: 11
# Running loglikelihood requests: 100% 74813/74813 [08:44<00:00, 142.61it/s]
# bootstrapping for stddev: perplexity
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 100% 100/100 [00:08<00:00, 11.70it/s]
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: tungserver99 (tunjob) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.26.1
# wandb: Run data is saved locally in /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/smart-flip/wandb/run-20260519_180121-0f28a2cn
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run gptq_smart_flip_Llama-3.1-8B_b3_k0.0_f0.05
# wandb: ⭐️ View project at https://wandb.ai/tunjob/egbc
# wandb: 🚀 View run at https://wandb.ai/tunjob/egbc/runs/0f28a2cn
# wandb: ⢿ updating run metadata (0.6s)
# wandb: ⣻ updating run metadata (0.6s)
# wandb: ⣽ updating run metadata (0.6s)
# wandb: ⣾ updating run metadata (0.6s)
# wandb: ⣷ uploading history steps 0-0, summary (0.1s)
# wandb: ⣯ uploading history steps 0-0, summary (0.1s)
# wandb: ⣟ uploading history steps 0-0, summary (0.1s)
# wandb: ⡿ uploading history steps 0-0, summary (0.1s)
# wandb: ⢿ uploading history steps 0-0, summary (0.1s)
# wandb:
# wandb: Run history:
# wandb:  lm_eval/arc_challenge ▁
# wandb:       lm_eval/arc_easy ▁
# wandb:          lm_eval/boolq ▁
# wandb:      lm_eval/hellaswag ▁
# wandb: lm_eval/lambada_openai ▁
# wandb:     lm_eval/openbookqa ▁
# wandb:           lm_eval/piqa ▁
# wandb:            lm_eval/rte ▁
# wandb:     lm_eval/winogrande ▁
# wandb:          perplexity/C4 ▁
# wandb:                     +1 ...
# wandb:
# wandb: Run summary:
# wandb:  lm_eval/arc_challenge 0.30717
# wandb:       lm_eval/arc_easy 0.60732
# wandb:          lm_eval/boolq 0.63731
# wandb:      lm_eval/hellaswag 0.43935
# wandb: lm_eval/lambada_openai 0.45837
# wandb:     lm_eval/openbookqa 0.214
# wandb:           lm_eval/piqa 0.71055
# wandb:            lm_eval/rte 0.53791
# wandb:     lm_eval/winogrande 0.62352
# wandb:             model_slug Llama-3p1-8B
# wandb:                     +4 ...
# wandb:
# wandb: 🚀 View run gptq_smart_flip_Llama-3.1-8B_b3_k0.0_f0.05 at: https://wandb.ai/tunjob/egbc/runs/0f28a2cn
# wandb: ⭐️ View project at: https://wandb.ai/tunjob/egbc
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260519_180121-0f28a2cn/logs
#
# Saved evaluation results to results/eval/gptq_smart_flip_Llama-3.1-8B_b3_k0.0_f0.05.json

# %%
# !bash scripts/bash/bias_correction/gptq/run_mistral_from_existing_raw_3bit.sh
# Out:
# ==> bias_correction from existing raw GPTQ :: ./results/models/gptq_raw/gptq_raw_Mistral-7B-v0.3
# Loading checkpoint shards: 100% 3/3 [00:00<00:00,  5.38it/s]
#
# [GPTQ Quantizer Initialized]
#   Config: GPTQConfig(bits=3, group_size=128, percdamp=0.01, sym=True, act_order=False, true_sequential=True, static_groups=False, mse=False, max_bias_samples=4096)
#   Post correction: BiasCorrectionCorrection
#
# Saved gptq_bias_correction model to results/models/gptq_bias_correction/gptq_bias_correction_Mistral-7B-v0.3_from_raw_b3
#
# Evaluating bias_correction_quantize on WikiText-2...
# Loading checkpoint shards: 100% 3/3 [00:13<00:00,  4.55s/it]
# Some weights of the model checkpoint at results/models/gptq_bias_correction/gptq_bias_correction_Mistral-7B-v0.3_from_raw_b3 were not used when initializing MistralForCausalLM: ['model.layers.0.mlp.down_proj.bias', 'model.layers.0.mlp.gate_proj.bias', 'model.layers.0.mlp.up_proj.bias', 'model.layers.0.self_attn.k_proj.bias', 'model.layers.0.self_attn.o_proj.bias', 'model.layers.0.self_attn.q_proj.bias', 'model.layers.0.self_attn.v_proj.bias', 'model.layers.1.mlp.down_proj.bias', 'model.layers.1.mlp.gate_proj.bias', 'model.layers.1.mlp.up_proj.bias', 'model.layers.1.self_attn.k_proj.bias', 'model.layers.1.self_attn.o_proj.bias', 'model.layers.1.self_attn.q_proj.bias', 'model.layers.1.self_attn.v_proj.bias', 'model.layers.10.mlp.down_proj.bias', 'model.layers.10.mlp.gate_proj.bias', 'model.layers.10.mlp.up_proj.bias', 'model.layers.10.self_attn.k_proj.bias', 'model.layers.10.self_attn.o_proj.bias', 'model.layers.10.self_attn.q_proj.bias', 'model.layers.10.self_attn.v_proj.bias', 'model.layers.11.mlp.down_proj.bias', 'model.layers.11.mlp.gate_proj.bias', 'model.layers.11.mlp.up_proj.bias', 'model.layers.11.self_attn.k_proj.bias', 'model.layers.11.self_attn.o_proj.bias', 'model.layers.11.self_attn.q_proj.bias', 'model.layers.11.self_attn.v_proj.bias', 'model.layers.12.mlp.down_proj.bias', 'model.layers.12.mlp.gate_proj.bias', 'model.layers.12.mlp.up_proj.bias', 'model.layers.12.self_attn.k_proj.bias', 'model.layers.12.self_attn.o_proj.bias', 'model.layers.12.self_attn.q_proj.bias', 'model.layers.12.self_attn.v_proj.bias', 'model.layers.13.mlp.down_proj.bias', 'model.layers.13.mlp.gate_proj.bias', 'model.layers.13.mlp.up_proj.bias', 'model.layers.13.self_attn.k_proj.bias', 'model.layers.13.self_attn.o_proj.bias', 'model.layers.13.self_attn.q_proj.bias', 'model.layers.13.self_attn.v_proj.bias', 'model.layers.14.mlp.down_proj.bias', 'model.layers.14.mlp.gate_proj.bias', 'model.layers.14.mlp.up_proj.bias', 'model.layers.14.self_attn.k_proj.bias', 'model.layers.14.self_attn.o_proj.bias', 'model.layers.14.self_attn.q_proj.bias', 'model.layers.14.self_attn.v_proj.bias', 'model.layers.15.mlp.down_proj.bias', 'model.layers.15.mlp.gate_proj.bias', 'model.layers.15.mlp.up_proj.bias', 'model.layers.15.self_attn.k_proj.bias', 'model.layers.15.self_attn.o_proj.bias', 'model.layers.15.self_attn.q_proj.bias', 'model.layers.15.self_attn.v_proj.bias', 'model.layers.16.mlp.down_proj.bias', 'model.layers.16.mlp.gate_proj.bias', 'model.layers.16.mlp.up_proj.bias', 'model.layers.16.self_attn.k_proj.bias', 'model.layers.16.self_attn.o_proj.bias', 'model.layers.16.self_attn.q_proj.bias', 'model.layers.16.self_attn.v_proj.bias', 'model.layers.17.mlp.down_proj.bias', 'model.layers.17.mlp.gate_proj.bias', 'model.layers.17.mlp.up_proj.bias', 'model.layers.17.self_attn.k_proj.bias', 'model.layers.17.self_attn.o_proj.bias', 'model.layers.17.self_attn.q_proj.bias', 'model.layers.17.self_attn.v_proj.bias', 'model.layers.18.mlp.down_proj.bias', 'model.layers.18.mlp.gate_proj.bias', 'model.layers.18.mlp.up_proj.bias', 'model.layers.18.self_attn.k_proj.bias', 'model.layers.18.self_attn.o_proj.bias', 'model.layers.18.self_attn.q_proj.bias', 'model.layers.18.self_attn.v_proj.bias', 'model.layers.19.mlp.down_proj.bias', 'model.layers.19.mlp.gate_proj.bias', 'model.layers.19.mlp.up_proj.bias', 'model.layers.19.self_attn.k_proj.bias', 'model.layers.19.self_attn.o_proj.bias', 'model.layers.19.self_attn.q_proj.bias', 'model.layers.19.self_attn.v_proj.bias', 'model.layers.2.mlp.down_proj.bias', 'model.layers.2.mlp.gate_proj.bias', 'model.layers.2.mlp.up_proj.bias', 'model.layers.2.self_attn.k_proj.bias', 'model.layers.2.self_attn.o_proj.bias', 'model.layers.2.self_attn.q_proj.bias', 'model.layers.2.self_attn.v_proj.bias', 'model.layers.20.mlp.down_proj.bias', 'model.layers.20.mlp.gate_proj.bias', 'model.layers.20.mlp.up_proj.bias', 'model.layers.20.self_attn.k_proj.bias', 'model.layers.20.self_attn.o_proj.bias', 'model.layers.20.self_attn.q_proj.bias', 'model.layers.20.sel ...
# - This IS expected if you are initializing MistralForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing MistralForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#
# Evaluating bias_correction_quantize on C4...
# Loading checkpoint shards: 100% 3/3 [00:11<00:00,  3.90s/it]
# Some weights of the model checkpoint at results/models/gptq_bias_correction/gptq_bias_correction_Mistral-7B-v0.3_from_raw_b3 were not used when initializing MistralForCausalLM: ['model.layers.0.mlp.down_proj.bias', 'model.layers.0.mlp.gate_proj.bias', 'model.layers.0.mlp.up_proj.bias', 'model.layers.0.self_attn.k_proj.bias', 'model.layers.0.self_attn.o_proj.bias', 'model.layers.0.self_attn.q_proj.bias', 'model.layers.0.self_attn.v_proj.bias', 'model.layers.1.mlp.down_proj.bias', 'model.layers.1.mlp.gate_proj.bias', 'model.layers.1.mlp.up_proj.bias', 'model.layers.1.self_attn.k_proj.bias', 'model.layers.1.self_attn.o_proj.bias', 'model.layers.1.self_attn.q_proj.bias', 'model.layers.1.self_attn.v_proj.bias', 'model.layers.10.mlp.down_proj.bias', 'model.layers.10.mlp.gate_proj.bias', 'model.layers.10.mlp.up_proj.bias', 'model.layers.10.self_attn.k_proj.bias', 'model.layers.10.self_attn.o_proj.bias', 'model.layers.10.self_attn.q_proj.bias', 'model.layers.10.self_attn.v_proj.bias', 'model.layers.11.mlp.down_proj.bias', 'model.layers.11.mlp.gate_proj.bias', 'model.layers.11.mlp.up_proj.bias', 'model.layers.11.self_attn.k_proj.bias', 'model.layers.11.self_attn.o_proj.bias', 'model.layers.11.self_attn.q_proj.bias', 'model.layers.11.self_attn.v_proj.bias', 'model.layers.12.mlp.down_proj.bias', 'model.layers.12.mlp.gate_proj.bias', 'model.layers.12.mlp.up_proj.bias', 'model.layers.12.self_attn.k_proj.bias', 'model.layers.12.self_attn.o_proj.bias', 'model.layers.12.self_attn.q_proj.bias', 'model.layers.12.self_attn.v_proj.bias', 'model.layers.13.mlp.down_proj.bias', 'model.layers.13.mlp.gate_proj.bias', 'model.layers.13.mlp.up_proj.bias', 'model.layers.13.self_attn.k_proj.bias', 'model.layers.13.self_attn.o_proj.bias', 'model.layers.13.self_attn.q_proj.bias', 'model.layers.13.self_attn.v_proj.bias', 'model.layers.14.mlp.down_proj.bias', 'model.layers.14.mlp.gate_proj.bias', 'model.layers.14.mlp.up_proj.bias', 'model.layers.14.self_attn.k_proj.bias', 'model.layers.14.self_attn.o_proj.bias', 'model.layers.14.self_attn.q_proj.bias', 'model.layers.14.self_attn.v_proj.bias', 'model.layers.15.mlp.down_proj.bias', 'model.layers.15.mlp.gate_proj.bias', 'model.layers.15.mlp.up_proj.bias', 'model.layers.15.self_attn.k_proj.bias', 'model.layers.15.self_attn.o_proj.bias', 'model.layers.15.self_attn.q_proj.bias', 'model.layers.15.self_attn.v_proj.bias', 'model.layers.16.mlp.down_proj.bias', 'model.layers.16.mlp.gate_proj.bias', 'model.layers.16.mlp.up_proj.bias', 'model.layers.16.self_attn.k_proj.bias', 'model.layers.16.self_attn.o_proj.bias', 'model.layers.16.self_attn.q_proj.bias', 'model.layers.16.self_attn.v_proj.bias', 'model.layers.17.mlp.down_proj.bias', 'model.layers.17.mlp.gate_proj.bias', 'model.layers.17.mlp.up_proj.bias', 'model.layers.17.self_attn.k_proj.bias', 'model.layers.17.self_attn.o_proj.bias', 'model.layers.17.self_attn.q_proj.bias', 'model.layers.17.self_attn.v_proj.bias', 'model.layers.18.mlp.down_proj.bias', 'model.layers.18.mlp.gate_proj.bias', 'model.layers.18.mlp.up_proj.bias', 'model.layers.18.self_attn.k_proj.bias', 'model.layers.18.self_attn.o_proj.bias', 'model.layers.18.self_attn.q_proj.bias', 'model.layers.18.self_attn.v_proj.bias', 'model.layers.19.mlp.down_proj.bias', 'model.layers.19.mlp.gate_proj.bias', 'model.layers.19.mlp.up_proj.bias', 'model.layers.19.self_attn.k_proj.bias', 'model.layers.19.self_attn.o_proj.bias', 'model.layers.19.self_attn.q_proj.bias', 'model.layers.19.self_attn.v_proj.bias', 'model.layers.2.mlp.down_proj.bias', 'model.layers.2.mlp.gate_proj.bias', 'model.layers.2.mlp.up_proj.bias', 'model.layers.2.self_attn.k_proj.bias', 'model.layers.2.self_attn.o_proj.bias', 'model.layers.2.self_attn.q_proj.bias', 'model.layers.2.self_attn.v_proj.bias', 'model.layers.20.mlp.down_proj.bias', 'model.layers.20.mlp.gate_proj.bias', 'model.layers.20.mlp.up_proj.bias', 'model.layers.20.self_attn.k_proj.bias', 'model.layers.20.self_attn.o_proj.bias', 'model.layers.20.self_attn.q_proj.bias', 'model.layers.20.sel ...
# - This IS expected if you are initializing MistralForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing MistralForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#
# Running lm-eval for bias_correction_quantize on arc_easy, arc_challenge, hellaswag, piqa, winogrande, boolq, rte, openbookqa, lambada_openai...
# 2026-05-20 05:29:21.358604: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-20 05:29:22.513961: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading checkpoint shards: 100% 3/3 [00:12<00:00,  4.20s/it]
# Some weights of the model checkpoint at results/models/gptq_bias_correction/gptq_bias_correction_Mistral-7B-v0.3_from_raw_b3 were not used when initializing MistralForCausalLM: ['model.layers.0.mlp.down_proj.bias', 'model.layers.0.mlp.gate_proj.bias', 'model.layers.0.mlp.up_proj.bias', 'model.layers.0.self_attn.k_proj.bias', 'model.layers.0.self_attn.o_proj.bias', 'model.layers.0.self_attn.q_proj.bias', 'model.layers.0.self_attn.v_proj.bias', 'model.layers.1.mlp.down_proj.bias', 'model.layers.1.mlp.gate_proj.bias', 'model.layers.1.mlp.up_proj.bias', 'model.layers.1.self_attn.k_proj.bias', 'model.layers.1.self_attn.o_proj.bias', 'model.layers.1.self_attn.q_proj.bias', 'model.layers.1.self_attn.v_proj.bias', 'model.layers.10.mlp.down_proj.bias', 'model.layers.10.mlp.gate_proj.bias', 'model.layers.10.mlp.up_proj.bias', 'model.layers.10.self_attn.k_proj.bias', 'model.layers.10.self_attn.o_proj.bias', 'model.layers.10.self_attn.q_proj.bias', 'model.layers.10.self_attn.v_proj.bias', 'model.layers.11.mlp.down_proj.bias', 'model.layers.11.mlp.gate_proj.bias', 'model.layers.11.mlp.up_proj.bias', 'model.layers.11.self_attn.k_proj.bias', 'model.layers.11.self_attn.o_proj.bias', 'model.layers.11.self_attn.q_proj.bias', 'model.layers.11.self_attn.v_proj.bias', 'model.layers.12.mlp.down_proj.bias', 'model.layers.12.mlp.gate_proj.bias', 'model.layers.12.mlp.up_proj.bias', 'model.layers.12.self_attn.k_proj.bias', 'model.layers.12.self_attn.o_proj.bias', 'model.layers.12.self_attn.q_proj.bias', 'model.layers.12.self_attn.v_proj.bias', 'model.layers.13.mlp.down_proj.bias', 'model.layers.13.mlp.gate_proj.bias', 'model.layers.13.mlp.up_proj.bias', 'model.layers.13.self_attn.k_proj.bias', 'model.layers.13.self_attn.o_proj.bias', 'model.layers.13.self_attn.q_proj.bias', 'model.layers.13.self_attn.v_proj.bias', 'model.layers.14.mlp.down_proj.bias', 'model.layers.14.mlp.gate_proj.bias', 'model.layers.14.mlp.up_proj.bias', 'model.layers.14.self_attn.k_proj.bias', 'model.layers.14.self_attn.o_proj.bias', 'model.layers.14.self_attn.q_proj.bias', 'model.layers.14.self_attn.v_proj.bias', 'model.layers.15.mlp.down_proj.bias', 'model.layers.15.mlp.gate_proj.bias', 'model.layers.15.mlp.up_proj.bias', 'model.layers.15.self_attn.k_proj.bias', 'model.layers.15.self_attn.o_proj.bias', 'model.layers.15.self_attn.q_proj.bias', 'model.layers.15.self_attn.v_proj.bias', 'model.layers.16.mlp.down_proj.bias', 'model.layers.16.mlp.gate_proj.bias', 'model.layers.16.mlp.up_proj.bias', 'model.layers.16.self_attn.k_proj.bias', 'model.layers.16.self_attn.o_proj.bias', 'model.layers.16.self_attn.q_proj.bias', 'model.layers.16.self_attn.v_proj.bias', 'model.layers.17.mlp.down_proj.bias', 'model.layers.17.mlp.gate_proj.bias', 'model.layers.17.mlp.up_proj.bias', 'model.layers.17.self_attn.k_proj.bias', 'model.layers.17.self_attn.o_proj.bias', 'model.layers.17.self_attn.q_proj.bias', 'model.layers.17.self_attn.v_proj.bias', 'model.layers.18.mlp.down_proj.bias', 'model.layers.18.mlp.gate_proj.bias', 'model.layers.18.mlp.up_proj.bias', 'model.layers.18.self_attn.k_proj.bias', 'model.layers.18.self_attn.o_proj.bias', 'model.layers.18.self_attn.q_proj.bias', 'model.layers.18.self_attn.v_proj.bias', 'model.layers.19.mlp.down_proj.bias', 'model.layers.19.mlp.gate_proj.bias', 'model.layers.19.mlp.up_proj.bias', 'model.layers.19.self_attn.k_proj.bias', 'model.layers.19.self_attn.o_proj.bias', 'model.layers.19.self_attn.q_proj.bias', 'model.layers.19.self_attn.v_proj.bias', 'model.layers.2.mlp.down_proj.bias', 'model.layers.2.mlp.gate_proj.bias', 'model.layers.2.mlp.up_proj.bias', 'model.layers.2.self_attn.k_proj.bias', 'model.layers.2.self_attn.o_proj.bias', 'model.layers.2.self_attn.q_proj.bias', 'model.layers.2.self_attn.v_proj.bias', 'model.layers.20.mlp.down_proj.bias', 'model.layers.20.mlp.gate_proj.bias', 'model.layers.20.mlp.up_proj.bias', 'model.layers.20.self_attn.k_proj.bias', 'model.layers.20.self_attn.o_proj.bias', 'model.layers.20.self_attn.q_proj.bias', 'model.layers.20.sel ...
# - This IS expected if you are initializing MistralForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing MistralForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading readme: 9.00kB [00:00, 4.03MB/s]
# Downloading data: 100% 331k/331k [00:00<00:00, 2.05MB/s]
# Downloading data: 100% 346k/346k [00:00<00:00, 4.80MB/s]
# Downloading data: 100% 86.1k/86.1k [00:00<00:00, 736kB/s]
# Generating train split: 100% 2251/2251 [00:00<00:00, 31576.30 examples/s]
# Generating test split: 100% 2376/2376 [00:00<00:00, 544452.92 examples/s]
# Generating validation split: 100% 570/570 [00:00<00:00, 255941.90 examples/s]
# Downloading data: 100% 190k/190k [00:00<00:00, 2.50MB/s]
# Downloading data: 100% 204k/204k [00:00<00:00, 3.11MB/s]
# Downloading data: 100% 55.7k/55.7k [00:00<00:00, 718kB/s]
# Generating train split: 100% 1119/1119 [00:00<00:00, 332113.37 examples/s]
# Generating test split: 100% 1172/1172 [00:00<00:00, 334630.65 examples/s]
# Generating validation split: 100% 299/299 [00:00<00:00, 157233.81 examples/s]
# Downloading readme: 7.02kB [00:00, 27.0MB/s]
# Downloading data: 100% 24.4M/24.4M [00:00<00:00, 123MB/s]
# Downloading data: 100% 6.11M/6.11M [00:00<00:00, 69.4MB/s]
# Downloading data: 100% 6.32M/6.32M [00:00<00:00, 70.7MB/s]
# Generating train split: 100% 39905/39905 [00:00<00:00, 262690.79 examples/s]
# Generating test split: 100% 10003/10003 [00:00<00:00, 302721.04 examples/s]
# Generating validation split: 100% 10042/10042 [00:00<00:00, 281257.81 examples/s]
# Map: 100% 39905/39905 [00:06<00:00, 6380.76 examples/s]
# Map: 100% 10042/10042 [00:01<00:00, 6861.29 examples/s]
# Downloading data: 100% 2.64M/2.64M [00:00<00:00, 35.9MB/s]
# Downloading data: 100% 300k/300k [00:00<00:00, 3.67MB/s]
# Downloading data: 100% 496k/496k [00:00<00:00, 6.86MB/s]
# Generating train split: 16113 examples [00:00, 1134930.15 examples/s]
# Generating validation split: 1838 examples [00:00, 630913.39 examples/s]
# Generating test split: 3084 examples [00:00, 865580.40 examples/s]
# Downloading readme: 11.2kB [00:00, 33.4MB/s]
# Downloading data: 100% 2.06M/2.06M [00:00<00:00, 16.5MB/s]
# Downloading data: 100% 118k/118k [00:00<00:00, 1.12MB/s]
# Downloading data: 100% 85.9k/85.9k [00:00<00:00, 668kB/s]
# Generating train split: 100% 40398/40398 [00:00<00:00, 1858828.29 examples/s]
# Generating test split: 100% 1767/1767 [00:00<00:00, 714345.56 examples/s]
# Generating validation split: 100% 1267/1267 [00:00<00:00, 572094.22 examples/s]
# WARNING:lm_eval.api.task:[Task: boolq] metric acc is defined, but aggregation is not. using default aggregation=mean
# WARNING:lm_eval.api.task:[Task: boolq] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# Downloading readme: 19.7kB [00:00, 58.8MB/s]
# Downloading data: 100% 3.85M/3.85M [00:00<00:00, 30.4MB/s]
# Downloading data: 100% 1.31M/1.31M [00:00<00:00, 11.1MB/s]
# Downloading data: 100% 1.31M/1.31M [00:00<00:00, 10.8MB/s]
# Generating train split: 100% 9427/9427 [00:00<00:00, 329508.52 examples/s]
# Generating validation split: 100% 3270/3270 [00:00<00:00, 337717.28 examples/s]
# Generating test split: 100% 3245/3245 [00:00<00:00, 268796.61 examples/s]
# WARNING:lm_eval.api.task:[Task: rte] metric acc is defined, but aggregation is not. using default aggregation=mean
# WARNING:lm_eval.api.task:[Task: rte] metric acc is defined, but higher_is_better is not. using default higher_is_better=True
# Downloading readme: 35.3kB [00:00, 73.5MB/s]
# Downloading data: 100% 584k/584k [00:00<00:00, 8.59MB/s]
# Downloading data: 100% 69.0k/69.0k [00:00<00:00, 1.11MB/s]
# Downloading data: 100% 621k/621k [00:00<00:00, 8.83MB/s]
# Generating train split: 100% 2490/2490 [00:00<00:00, 419514.64 examples/s]
# Generating validation split: 100% 277/277 [00:00<00:00, 142677.42 examples/s]
# Generating test split: 100% 3000/3000 [00:00<00:00, 533943.48 examples/s]
# Downloading readme: 9.06kB [00:00, 29.6MB/s]
# Downloading data: 100% 496k/496k [00:00<00:00, 3.60MB/s]
# Downloading data: 100% 58.2k/58.2k [00:00<00:00, 534kB/s]
# Downloading data: 100% 55.5k/55.5k [00:00<00:00, 499kB/s]
# Generating train split: 100% 4957/4957 [00:00<00:00, 763735.26 examples/s]
# Generating validation split: 100% 500/500 [00:00<00:00, 220962.17 examples/s]
# Generating test split: 100% 500/500 [00:00<00:00, 231371.58 examples/s]
# Downloading readme: 5.47kB [00:00, 20.0MB/s]
# Downloading data: 100% 1.16M/1.16M [00:00<00:00, 15.1MB/s]
# Generating test split: 100% 5153/5153 [00:00<00:00, 439302.60 examples/s]
# 100% 5153/5153 [00:09<00:00, 556.08it/s]
# 100% 500/500 [00:00<00:00, 1943.40it/s]
# 100% 277/277 [00:00<00:00, 1815.75it/s]
# 100% 3270/3270 [00:01<00:00, 1821.38it/s]
# 100% 1267/1267 [00:00<00:00, 100786.75it/s]
# 100% 1838/1838 [00:01<00:00, 1014.46it/s]
# 100% 10042/10042 [00:04<00:00, 2179.98it/s]
# 100% 1172/1172 [00:01<00:00, 1041.70it/s]
# 100% 2376/2376 [00:02<00:00, 1051.14it/s]
# Running loglikelihood requests:   0% 0/74813 [00:00<?, ?it/s]Passed argument batch_size = auto:1. Detecting largest batch size
# Starting from v4.46, the `logits` model output will have the same type as the model (except at train time, where it will always be FP32)
# Determined largest batch size: 32
# Running loglikelihood requests: 100% 74813/74813 [08:09<00:00, 152.88it/s]
# bootstrapping for stddev: perplexity
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 100% 100/100 [00:08<00:00, 11.41it/s]
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: tungserver99 (tunjob) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.26.1
# wandb: Run data is saved locally in /content/drive/Othercomputers/My Computer/Google Drive Offline/PHD/Quantization/smart-flip/wandb/run-20260520_053957-anrq4hca
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run gptq_bias_correction_Mistral-7B-v0.3_from_raw_b3
# wandb: ⭐️ View project at https://wandb.ai/tunjob/egbc
# wandb: 🚀 View run at https://wandb.ai/tunjob/egbc/runs/anrq4hca
# wandb: ⢿ updating run metadata (0.7s)
# wandb: ⣻ updating run metadata (0.7s)
# wandb: ⣽ updating run metadata (0.7s)
# wandb: ⣾ updating run metadata (0.7s)
# wandb: ⣷ uploading history steps 0-0, summary (0.1s)
# wandb: ⣯ uploading history steps 0-0, summary (0.1s)
# wandb:
# wandb: Run history:
# wandb:  lm_eval/arc_challenge ▁
# wandb:       lm_eval/arc_easy ▁
# wandb:          lm_eval/boolq ▁
# wandb:      lm_eval/hellaswag ▁
# wandb: lm_eval/lambada_openai ▁
# wandb:     lm_eval/openbookqa ▁
# wandb:           lm_eval/piqa ▁
# wandb:            lm_eval/rte ▁
# wandb:     lm_eval/winogrande ▁
# wandb:          perplexity/C4 ▁
# wandb:                     +1 ...
# wandb:
# wandb: Run summary:
# wandb:  lm_eval/arc_challenge 0.44966
# wandb:       lm_eval/arc_easy 0.77399
# wandb:          lm_eval/boolq 0.81009
# wandb:      lm_eval/hellaswag 0.58913
# wandb: lm_eval/lambada_openai 0.7093
# wandb:     lm_eval/openbookqa 0.336
# wandb:           lm_eval/piqa 0.78999
# wandb:            lm_eval/rte 0.66426
# wandb:     lm_eval/winogrande 0.71902
# wandb:             model_slug Mistral-7B-v0.3
# wandb:                     +4 ...
# wandb:
# wandb: 🚀 View run gptq_bias_correction_Mistral-7B-v0.3_from_raw_b3 at: https://wandb.ai/tunjob/egbc/runs/anrq4hca
# wandb: ⭐️ View project at: https://wandb.ai/tunjob/egbc
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260520_053957-anrq4hca/logs
#
# Saved evaluation results to results/eval/gptq_bias_correction_Mistral-7B-v0.3_from_raw_b3.json
